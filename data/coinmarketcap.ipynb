# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '8156fd5c-1e27-4c73-8393-fef3b616fe8d',
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    data = data['data']
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)

# %%
data
# Out:
# [{'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'slug': 'bitcoin',
#   'num_market_pairs': 7719,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000,
#   'circulating_supply': 18083175,
#   'total_supply': 18083175,
#   'platform': None,
#   'cmc_rank': 1,
#   'last_updated': '2019-12-04T19:20:35.000Z',
#   'quote': {'USD': {'price': 7482.23634438,
#     'volume_24h': 19700326607.9254,
#     'percent_change_1h': 0.197143,
#     'percent_change_24h': 1.41296,
#     'percent_change_7d': 0.144989,
#     'market_cap': 135302589206.78381,
#     'last_updated': '2019-12-04T19:20:35.000Z'}}},
#  {'id': 1027,
#   'name': 'Ethereum',
#   'symbol': 'ETH',
#   'slug': 'ethereum',
#   'num_market_pairs': 5335,
#   'date_added': '2015-08-07T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 108797734.1865,
#   'total_supply': 108797734.1865,
#   'platform': None,
#   'cmc_rank': 2,
#   'last_updated': '2019-12-04T19:20:23.000Z',
#   'quote': {'USD': {'price': 149.919776074,
#     'volume_24h': 7507420167.18814,
#     'percent_change_1h': 0.188716,
#     'percent_change_24h': 0.547404,
#     'percent_change_7d': -1.65642,
#     'market_cap': 16310931946.598654,
#     'last_updated': '2019-12-04T19:20:23.000Z'}}},
#  {'id': 52,
#   'name': 'XRP',
#   'symbol': 'XRP',
#   'slug': 'xrp',
#   'num_market_pairs': 508,
#   'date_added': '2013-08-04T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 100000000000,
#   'circulating_supply': 43285660917,
#   'total_supply': 99991237614,
#   'platform': None,
#   'cmc_rank': 3,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': {'USD': {'price': 0.219962992085,
#     'volume_24h': 1335180545.85316,
#     'percent_change_1h': 0.126669,
#     'percent_change_24h': -0.717002,
#     'percent_change_7d': -2.11289,
#     'market_cap': 9521243489.680065,
#     'last_updated': '2019-12-04T19:20:05.000Z'}}},
#  {'id': 825,
#   'name': 'Tether',
#   'symbol': 'USDT',
#   'slug': 'tether',
#   'num_market_pairs': 3926,
#   'date_added': '2015-02-25T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 4108044456.1,
#   'total_supply': 4207771504.46,
#   'platform': {'id': 83,
#    'name': 'Omni',
#    'symbol': 'OMNI',
#    'slug': 'omni',
#    'token_address': '31'},
#   'cmc_rank': 4,
#   'last_updated': '2019-12-04T19:20:20.000Z',
#   'quote': {'USD': {'price': 1.00120091889,
#     'volume_24h': 22436631226.8141,
#     'percent_change_1h': -0.0402205,
#     'percent_change_24h': -0.547525,
#     'percent_change_7d': -0.231595,
#     'market_cap': 4112977884.28829,
#     'last_updated': '2019-12-04T19:20:20.000Z'}}},
#  {'id': 1831,
#   'name': 'Bitcoin Cash',
#   'symbol': 'BCH',
#   'slug': 'bitcoin-cash',
#   'num_market_pairs': 440,
#   'date_added': '2017-07-23T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000,
#   'circulating_supply': 18148862.5,
#   'total_supply': 18148862.5,
#   'platform': None,
#   'cmc_rank': 5,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': {'USD': {'price': 213.261674607,
#     'volume_24h': 1387373968.28986,
#     'percent_change_1h': -0.0804162,
#     'percent_change_24h': -0.749894,
#     'percent_change_7d': -2.7391,
#     'market_cap': 3870456808.9621844,
#     'last_updated': '2019-12-04T19:20:07.000Z'}}},
#  {'id': 2,
#   'name': 'Litecoin',
#   'symbol': 'LTC',
#   'slug': 'litecoin',
#   'num_market_pairs': 557,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 84000000,
#   'circulating_supply': 63769621.4851745,
#   'total_supply': 63769621.4851745,
#   'platform': None,
#   'cmc_rank': 6,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': {'USD': {'price': 45.9525246749,
#     'volume_24h': 2848604214.87534,
#     'percent_change_1h': -0.00476396,
#     'percent_change_24h': -0.535424,
#     'percent_change_7d': -3.94367,
#     'market_cap': 2930375104.8065143,
#     'last_updated': '2019-12-04T19:20:04.000Z'}}},
#  {'id': 1765,
#   'name': 'EOS',
#   'symbol': 'EOS',
#   'slug': 'eos',
#   'num_market_pairs': 394,
#   'date_added': '2017-07-01T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 942947039.0316,
#   'total_supply': 1039647050.5237,
#   'platform': None,
#   'cmc_rank': 7,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': {'USD': {'price': 2.68567848224,
#     'volume_24h': 1851143317.76617,
#     'percent_change_1h': -0.123179,
#     'percent_change_24h': -1.39988,
#     'percent_change_7d': 0.414712,
#     'market_cap': 2532452572.6190896,
#     'last_updated': '2019-12-04T19:20:07.000Z'}}},
#  {'id': 1839,
#   'name': 'Binance Coin',
#   'symbol': 'BNB',
#   'slug': 'binance-coin',
#   'num_market_pairs': 283,
#   'date_added': '2017-07-25T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 187536713,
#   'circulating_supply': 155536713,
#   'total_supply': 187536713,
#   'platform': None,
#   'cmc_rank': 8,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': {'USD': {'price': 15.5670066407,
#     'volume_24h': 238384715.777762,
#     'percent_change_1h': -0.0258159,
#     'percent_change_24h': 0.650962,
#     'percent_change_7d': -2.05264,
#     'market_cap': 2421241044.14365,
#     'last_updated': '2019-12-04T19:20:06.000Z'}}},
#  {'id': 3602,
#   'name': 'Bitcoin SV',
#   'symbol': 'BSV',
#   'slug': 'bitcoin-sv',
#   'num_market_pairs': 154,
#   'date_added': '2018-11-09T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000,
#   'circulating_supply': 18068415,
#   'total_supply': 18068415,
#   'platform': None,
#   'cmc_rank': 9,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': {'USD': {'price': 96.5390247628,
#     'volume_24h': 464651325.711624,
#     'percent_change_1h': -0.963822,
#     'percent_change_24h': -1.13302,
#     'percent_change_7d': -10.7485,
#     'market_cap': 1744307163.109547,
#     'last_updated': '2019-12-04T19:20:11.000Z'}}},
#  {'id': 512,
#   'name': 'Stellar',
#   'symbol': 'XLM',
#   'slug': 'stellar',
#   'num_market_pairs': 306,
#   'date_added': '2014-08-05T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 20054779553.7,
#   'total_supply': 50000000000,
#   'platform': None,
#   'cmc_rank': 10,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': {'USD': {'price': 0.0562347498679,
#     'volume_24h': 188321324.618585,
#     'percent_change_1h': 0.0129357,
#     'percent_change_24h': -0.467622,
#     'percent_change_7d': -4.47741,
#     'market_cap': 1127775511.8581948,
#     'last_updated': '2019-12-04T19:20:05.000Z'}}},
#  {'id': 2010,
#   'name': 'Cardano',
#   'symbol': 'ADA',
#   'slug': 'cardano',
#   'num_market_pairs': 118,
#   'date_added': '2017-10-01T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 45000000000,
#   'circulating_supply': 25927070538,
#   'total_supply': 31112483745,
#   'platform': None,
#   'cmc_rank': 11,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': {'USD': {'price': 0.0381808694413,
#     'volume_24h': 47361069.5181307,
#     'percent_change_1h': 0.952286,
#     'percent_change_24h': -0.678036,
#     'percent_change_7d': -2.20113,
#     'market_cap': 989918095.2067538,
#     'last_updated': '2019-12-04T19:20:06.000Z'}}},
#  {'id': 1958,
#   'name': 'TRON',
#   'symbol': 'TRX',
#   'slug': 'tron',
#   'num_market_pairs': 300,
#   'date_added': '2017-09-13T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 66682072191.4,
#   'total_supply': 99281283754.3,
#   'platform': None,
#   'cmc_rank': 12,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': {'USD': {'price': 0.014723435744,
#     'volume_24h': 976121767.348244,
#     'percent_change_1h': 0.150534,
#     'percent_change_24h': -4.91687,
#     'percent_change_7d': -8.04652,
#     'market_cap': 981789205.1868472,
#     'last_updated': '2019-12-04T19:20:07.000Z'}}},
#  {'id': 328,
#   'name': 'Monero',
#   'symbol': 'XMR',
#   'slug': 'monero',
#   'num_market_pairs': 129,
#   'date_added': '2014-05-21T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 17339143.656908,
#   'total_supply': 17339143.656908,
#   'platform': None,
#   'cmc_rank': 13,
#   'last_updated': '2019-12-04T19:20:03.000Z',
#   'quote': {'USD': {'price': 54.3602492324,
#     'volume_24h': 151745948.423245,
#     'percent_change_1h': 0.181514,
#     'percent_change_24h': 0.255069,
#     'percent_change_7d': -1.59702,
#     'market_cap': 942560170.6659065,
#     'last_updated': '2019-12-04T19:20:03.000Z'}}},
#  {'id': 3957,
#   'name': 'UNUS SED LEO',
#   'symbol': 'LEO',
#   'slug': 'unus-sed-leo',
#   'num_market_pairs': 26,
#   'date_added': '2019-05-21T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 999498892.9,
#   'total_supply': 999498892.9,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3'},
#   'cmc_rank': 14,
#   'last_updated': '2019-12-04T19:20:12.000Z',
#   'quote': {'USD': {'price': 0.920145328717,
#     'volume_24h': 6694893.91684225,
#     'percent_change_1h': 0.139412,
#     'percent_change_24h': 0.105327,
#     'percent_change_7d': 1.5927,
#     'market_cap': 919684237.3597481,
#     'last_updated': '2019-12-04T19:20:12.000Z'}}},
#  {'id': 2011,
#   'name': 'Tezos',
#   'symbol': 'XTZ',
#   'slug': 'tezos',
#   'num_market_pairs': 55,
#   'date_added': '2017-10-02T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 660373611.97278,
#   'total_supply': 801312599.488106,
#   'platform': None,
#   'cmc_rank': 15,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': {'USD': {'price': 1.28909973789,
#     'volume_24h': 45356323.5982943,
#     'percent_change_1h': 0.15219,
#     'percent_change_24h': 0.0950627,
#     'percent_change_7d': 4.75011,
#     'market_cap': 851287450.1035832,
#     'last_updated': '2019-12-04T19:20:06.000Z'}}},
#  {'id': 1975,
#   'name': 'Chainlink',
#   'symbol': 'LINK',
#   'slug': 'chainlink',
#   'num_market_pairs': 120,
#   'date_added': '2017-09-20T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 350000000,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#   'cmc_rank': 16,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': {'USD': {'price': 2.08880910384,
#     'volume_24h': 145444198.2028,
#     'percent_change_1h': -0.00633818,
#     'percent_change_24h': -3.53193,
#     'percent_change_7d': -6.7752,
#     'market_cap': 731083186.344,
#     'last_updated': '2019-12-04T19:20:06.000Z'}}},
#  {'id': 3794,
#   'name': 'Cosmos',
#   'symbol': 'ATOM',
#   'slug': 'cosmos',
#   'num_market_pairs': 99,
#   'date_added': '2019-03-14T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 190688439.2,
#   'total_supply': 237928230.821588,
#   'platform': None,
#   'cmc_rank': 17,
#   'last_updated': '2019-12-04T19:20:12.000Z',
#   'quote': {'USD': {'price': 3.6735316903,
#     'volume_24h': 178453229.17891,
#     'percent_change_1h': 0.184584,
#     'percent_change_24h': -1.37381,
#     'percent_change_7d': 2.2891,
#     'market_cap': 700500024.3750447,
#     'last_updated': '2019-12-04T19:20:12.000Z'}}},
#  {'id': 2502,
#   'name': 'Huobi Token',
#   'symbol': 'HT',
#   'slug': 'huobi-token',
#   'num_market_pairs': 128,
#   'date_added': '2018-02-03T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 241284046.971921,
#   'total_supply': 500000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x6f259637dcd74c767781e37bc6133cd6a68aa161'},
#   'cmc_rank': 18,
#   'last_updated': '2019-12-04T19:20:09.000Z',
#   'quote': {'USD': {'price': 2.89276719872,
#     'volume_24h': 137193012.920879,
#     'percent_change_1h': 0.171428,
#     'percent_change_24h': -3.4031,
#     'percent_change_7d': 10.5851,
#     'market_cap': 697978576.6547889,
#     'last_updated': '2019-12-04T19:20:09.000Z'}}},
#  {'id': 1376,
#   'name': 'NEO',
#   'symbol': 'NEO',
#   'slug': 'neo',
#   'num_market_pairs': 226,
#   'date_added': '2016-09-08T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 100000000,
#   'circulating_supply': 70538831,
#   'total_supply': 100000000,
#   'platform': None,
#   'cmc_rank': 19,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': {'USD': {'price': 8.96789256966,
#     'volume_24h': 325070337.930739,
#     'percent_change_1h': 0.180901,
#     'percent_change_24h': -1.2642,
#     'percent_change_7d': -5.18028,
#     'market_cap': 632584658.3974025,
#     'last_updated': '2019-12-04T19:20:05.000Z'}}},
#  {'id': 1720,
#   'name': 'IOTA',
#   'symbol': 'MIOTA',
#   'slug': 'iota',
#   'num_market_pairs': 48,
#   'date_added': '2017-06-13T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 2779530283,
#   'circulating_supply': 2779530283,
#   'total_supply': 2779530283,
#   'platform': None,
#   'cmc_rank': 20,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': {'USD': {'price': 0.203352198942,
#     'volume_24h': 7495166.72167913,
#     'percent_change_1h': 0.158976,
#     'percent_change_24h': -0.979434,
#     'percent_change_7d': -4.66745,
#     'market_cap': 565223595.0739295,
#     'last_updated': '2019-12-04T19:20:05.000Z'}}},
#  {'id': 1518,
#   'name': 'Maker',
#   'symbol': 'MKR',
#   'slug': 'maker',
#   'num_market_pairs': 70,
#   'date_added': '2017-01-29T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 1000000,
#   'total_supply': 1000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2'},
#   'cmc_rank': 21,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': {'USD': {'price': 553.309127757,
#     'volume_24h': 4797859.89938121,
#     'percent_change_1h': 0.162512,
#     'percent_change_24h': 0.12493,
#     'percent_change_7d': 0.51792,
#     'market_cap': 553309127.7570001,
#     'last_updated': '2019-12-04T19:20:05.000Z'}}},
#  {'id': 131,
#   'name': 'Dash',
#   'symbol': 'DASH',
#   'slug': 'dash',
#   'num_market_pairs': 271,
#   'date_added': '2014-02-14T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 18900000,
#   'circulating_supply': 9193090.33231986,
#   'total_supply': 9193090.33231986,
#   'platform': None,
#   'cmc_rank': 22,
#   'last_updated': '2019-12-04T19:20:03.000Z',
#   'quote': {'USD': {'price': 51.6270959696,
#     'volume_24h': 237911664.449504,
#     'percent_change_1h': 0.000703554,
#     'percent_change_24h': -0.745942,
#     'percent_change_7d': 0.518914,
#     'market_cap': 474612556.84387934,
#     'last_updated': '2019-12-04T19:20:03.000Z'}}},
#  {'id': 3408,
#   'name': 'USD Coin',
#   'symbol': 'USDC',
#   'slug': 'usd-coin',
#   'num_market_pairs': 182,
#   'date_added': '2018-10-08T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 462767535.369803,
#   'total_supply': 465405615.55,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   'cmc_rank': 23,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': {'USD': {'price': 1.00097589981,
#     'volume_24h': 244647123.332586,
#     'percent_change_1h': -0.00390579,
#     'percent_change_24h': -0.483248,
#     'percent_change_7d': -0.595499,
#     'market_cap': 463219150.1196446,
#     'last_updated': '2019-12-04T19:20:11.000Z'}}},
#  {'id': 1321,
#   'name': 'Ethereum Classic',
#   'symbol': 'ETC',
#   'slug': 'ethereum-classic',
#   'num_market_pairs': 220,
#   'date_added': '2016-07-24T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 210000000,
#   'circulating_supply': 115607209,
#   'total_supply': 115607209,
#   'platform': None,
#   'cmc_rank': 24,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': {'USD': {'price': 3.82643907131,
#     'volume_24h': 477342310.40406,
#     'percent_change_1h': -0.0743505,
#     'percent_change_24h': -1.41699,
#     'percent_change_7d': -3.15438,
#     'market_cap': 442363941.44270104,
#     'last_updated': '2019-12-04T19:20:05.000Z'}}},
#  {'id': 3077,
#   'name': 'VeChain',
#   'symbol': 'VET',
#   'slug': 'vechain',
#   'num_market_pairs': 85,
#   'date_added': '2017-08-22T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 55454734800,
#   'total_supply': 86712634466,
#   'platform': None,
#   'cmc_rank': 25,
#   'last_updated': '2019-12-04T19:20:10.000Z',
#   'quote': {'USD': {'price': 0.00729366140938,
#     'volume_24h': 133521843.816197,
#     'percent_change_1h': -0.421172,
#     'percent_change_24h': 5.00532,
#     'percent_change_7d': 11.795,
#     'market_cap': 404468059.17816216,
#     'last_updated': '2019-12-04T19:20:10.000Z'}}},
#  {'id': 2566,
#   'name': 'Ontology',
#   'symbol': 'ONT',
#   'slug': 'ontology',
#   'num_market_pairs': 106,
#   'date_added': '2018-03-08T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 637351170,
#   'total_supply': 1000000000,
#   'platform': None,
#   'cmc_rank': 26,
#   'last_updated': '2019-12-04T19:20:09.000Z',
#   'quote': {'USD': {'price': 0.61290912343,
#     'volume_24h': 75279648.9337707,
#     'percent_change_1h': 0.33051,
#     'percent_change_24h': -2.01025,
#     'percent_change_7d': -4.48937,
#     'market_cap': 390638346.92178494,
#     'last_updated': '2019-12-04T19:20:09.000Z'}}},
#  {'id': 873,
#   'name': 'NEM',
#   'symbol': 'XEM',
#   'slug': 'nem',
#   'num_market_pairs': 96,
#   'date_added': '2015-04-01T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 8999999999,
#   'total_supply': 8999999999,
#   'platform': None,
#   'cmc_rank': 27,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': {'USD': {'price': 0.0362294312344,
#     'volume_24h': 10571262.8027508,
#     'percent_change_1h': -0.0637937,
#     'percent_change_24h': 2.47762,
#     'percent_change_7d': -1.95211,
#     'market_cap': 326064881.0733706,
#     'last_updated': '2019-12-04T19:20:04.000Z'}}},
#  {'id': 3635,
#   'name': 'Crypto.com Coin',
#   'symbol': 'CRO',
#   'slug': 'crypto-com-coin',
#   'num_market_pairs': 38,
#   'date_added': '2018-12-14T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 12105022831.0502,
#   'total_supply': 100000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#   'cmc_rank': 28,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': {'USD': {'price': 0.0267814655279,
#     'volume_24h': 2407485.24216371,
#     'percent_change_1h': -0.261708,
#     'percent_change_24h': 2.24924,
#     'percent_change_7d': -5.32955,
#     'market_cap': 324190251.66421336,
#     'last_updated': '2019-12-04T19:20:11.000Z'}}},
#  {'id': 74,
#   'name': 'Dogecoin',
#   'symbol': 'DOGE',
#   'slug': 'dogecoin',
#   'num_market_pairs': 287,
#   'date_added': '2013-12-15T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 122327110779.95,
#   'total_supply': 122327110779.95,
#   'platform': None,
#   'cmc_rank': 29,
#   'last_updated': '2019-12-04T19:20:03.000Z',
#   'quote': {'USD': {'price': 0.00222066768299,
#     'volume_24h': 70459840.0913846,
#     'percent_change_1h': 0.0953186,
#     'percent_change_24h': 0.136223,
#     'percent_change_7d': -4.55616,
#     'market_cap': 271647861.6625726,
#     'last_updated': '2019-12-04T19:20:03.000Z'}}},
#  {'id': 1697,
#   'name': 'Basic Attention Token',
#   'symbol': 'BAT',
#   'slug': 'basic-attention-token',
#   'num_market_pairs': 161,
#   'date_added': '2017-06-01T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 1356449188.9763,
#   'total_supply': 1500000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x0d8775f648430679a709e98d2b0cb6250d2887ef'},
#   'cmc_rank': 30,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': {'USD': {'price': 0.186224551553,
#     'volume_24h': 60222368.651241,
#     'percent_change_1h': 0.463359,
#     'percent_change_24h': -5.12395,
#     'percent_change_7d': -9.25158,
#     'market_cap': 252604141.92154202,
#     'last_updated': '2019-12-04T19:20:06.000Z'}}},
#  {'id': 3330,
#   'name': 'Paxos Standard',
#   'symbol': 'PAX',
#   'slug': 'paxos-standard',
#   'num_market_pairs': 96,
#   'date_added': '2018-09-27T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 240112317.416244,
#   'total_supply': 240112398.55,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x8e870d67f660d95d5be530380d0ec0bd388289e1'},
#   'cmc_rank': 31,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': {'USD': {'price': 1.00208144512,
#     'volume_24h': 182792960.19608,
#     'percent_change_1h': 0.0175263,
#     'percent_change_24h': -0.377911,
#     'percent_change_7d': -0.0740385,
#     'market_cap': 240612098.02758193,
#     'last_updated': '2019-12-04T19:20:11.000Z'}}},
#  {'id': 1437,
#   'name': 'Zcash',
#   'symbol': 'ZEC',
#   'slug': 'zcash',
#   'num_market_pairs': 223,
#   'date_added': '2016-10-29T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 7993931.25,
#   'total_supply': 7993931.25,
#   'platform': None,
#   'cmc_rank': 32,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': {'USD': {'price': 27.4154706051,
#     'volume_24h': 115597844.932199,
#     'percent_change_1h': -0.0386922,
#     'percent_change_24h': -1.04238,
#     'percent_change_7d': -4.50526,
#     'market_cap': 219157387.2035653,
#     'last_updated': '2019-12-04T19:20:06.000Z'}}},
#  {'id': 3662,
#   'name': 'HedgeTrade',
#   'symbol': 'HEDG',
#   'slug': 'hedgetrade',
#   'num_market_pairs': 8,
#   'date_added': '2019-01-03T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 288114855.057208,
#   'total_supply': 1000000000.05,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xF1290473E210b2108A85237fbCd7b6eb42Cc654F'},
#   'cmc_rank': 33,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': {'USD': {'price': 0.730185492333,
#     'volume_24h': 323624.224835945,
#     'percent_change_1h': 2.48145,
#     'percent_change_24h': 1.98641,
#     'percent_change_7d': 13.1723,
#     'market_cap': 210377287.28839836,
#     'last_updated': '2019-12-04T19:20:11.000Z'}}},
#  {'id': 1168,
#   'name': 'Decred',
#   'symbol': 'DCR',
#   'slug': 'decred',
#   'num_market_pairs': 47,
#   'date_added': '2016-02-10T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000,
#   'circulating_supply': 10766858.9251755,
#   'total_supply': 10766858.9251755,
#   'platform': None,
#   'cmc_rank': 34,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': {'USD': {'price': 19.4555305973,
#     'volume_24h': 6260557.41025565,
#     'percent_change_1h': 0.172036,
#     'percent_change_24h': 4.17156,
#     'percent_change_7d': 6.15281,
#     'market_cap': 209474953.25556454,
#     'last_updated': '2019-12-04T19:20:04.000Z'}}},
#  {'id': 3296,
#   'name': 'MINDOL',
#   'symbol': 'MIN',
#   'slug': 'mindol',
#   'num_market_pairs': 13,
#   'date_added': '2019-03-29T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 141690716,
#   'total_supply': 240000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x5d64d850c8368008afb39224e92ad0dceff3cf38'},
#   'cmc_rank': 35,
#   'last_updated': '2019-12-04T19:20:10.000Z',
#   'quote': {'USD': {'price': 1.46635204166,
#     'volume_24h': 3487587.8291966,
#     'percent_change_1h': -6.94336,
#     'percent_change_24h': -39.163,
#     'percent_change_7d': -38.1138,
#     'market_cap': 207768470.69086722,
#     'last_updated': '2019-12-04T19:20:10.000Z'}}},
#  {'id': 2586,
#   'name': 'Synthetix Network Token',
#   'symbol': 'SNX',
#   'slug': 'synthetix-network-token',
#   'num_market_pairs': 7,
#   'date_added': '2018-03-14T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 148341865.825791,
#   'total_supply': 154807692.307692,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xc011a72400e58ecd99ee497cf89e3775d4bd732f'},
#   'cmc_rank': 36,
#   'last_updated': '2019-12-04T19:20:08.000Z',
#   'quote': {'USD': {'price': 1.31069029834,
#     'volume_24h': 401976.801478849,
#     'percent_change_1h': 0.90718,
#     'percent_change_24h': -4.95817,
#     'percent_change_7d': -7.59629,
#     'market_cap': 194430244.37551826,
#     'last_updated': '2019-12-04T19:20:08.000Z'}}},
#  {'id': 1684,
#   'name': 'Qtum',
#   'symbol': 'QTUM',
#   'slug': 'qtum',
#   'num_market_pairs': 178,
#   'date_added': '2017-05-24T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 107822406,
#   'circulating_supply': 96211668.0484598,
#   'total_supply': 101961688,
#   'platform': None,
#   'cmc_rank': 37,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': {'USD': {'price': 1.75054251617,
#     'volume_24h': 265141807.808634,
#     'percent_change_1h': 0.091237,
#     'percent_change_24h': -1.52741,
#     'percent_change_7d': 1.98108,
#     'market_cap': 168422615.4704636,
#     'last_updated': '2019-12-04T19:20:06.000Z'}}},
#  {'id': 2563,
#   'name': 'TrueUSD',
#   'symbol': 'TUSD',
#   'slug': 'trueusd',
#   'num_market_pairs': 147,
#   'date_added': '2018-03-06T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 157940044.67,
#   'total_supply': 157940044.67,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x0000000000085d4780B73119b644AE5ecd22b376'},
#   'cmc_rank': 38,
#   'last_updated': '2019-12-04T19:20:09.000Z',
#   'quote': {'USD': {'price': 0.997746188713,
#     'volume_24h': 200190755.152642,
#     'percent_change_1h': 0.00184331,
#     'percent_change_24h': -0.448822,
#     'percent_change_7d': -0.583766,
#     'market_cap': 157584077.61465347,
#     'last_updated': '2019-12-04T19:20:09.000Z'}}},
#  {'id': 2585,
#   'name': 'Centrality',
#   'symbol': 'CENNZ',
#   'slug': 'centrality',
#   'num_market_pairs': 2,
#   'date_added': '2018-03-13T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 1069176371.64951,
#   'total_supply': 1200000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x1122b6a0e00dce0563082b6e2953f3a943855c1f'},
#   'cmc_rank': 39,
#   'last_updated': '2019-12-04T19:20:08.000Z',
#   'quote': {'USD': {'price': 0.136474039064,
#     'volume_24h': 373358.509032478,
#     'percent_change_1h': 1.09836,
#     'percent_change_24h': -0.850778,
#     'percent_change_7d': -5.93108,
#     'market_cap': 145914817.910801,
#     'last_updated': '2019-12-04T19:20:08.000Z'}}},
#  {'id': 1896,
#   'name': '0x',
#   'symbol': 'ZRX',
#   'slug': '0x',
#   'num_market_pairs': 175,
#   'date_added': '2017-08-16T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 602160071.148669,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xe41d2489571d322189246dafa5ebde1f4699f498'},
#   'cmc_rank': 40,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': {'USD': {'price': 0.240301663872,
#     'volume_24h': 13206734.0883647,
#     'percent_change_1h': -0.0259144,
#     'percent_change_24h': -3.2565,
#     'percent_change_7d': -7.25291,
#     'market_cap': 144700067.01430705,
#     'last_updated': '2019-12-04T19:20:06.000Z'}}},
#  {'id': 2577,
#   'name': 'Ravencoin',
#   'symbol': 'RVN',
#   'slug': 'ravencoin',
#   'num_market_pairs': 45,
#   'date_added': '2018-03-10T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000000,
#   'circulating_supply': 4996865000,
#   'total_supply': 4996865000,
#   'platform': None,
#   'cmc_rank': 41,
#   'last_updated': '2019-12-04T19:20:08.000Z',
#   'quote': {'USD': {'price': 0.0279671388459,
#     'volume_24h': 39395941.0381757,
#     'percent_change_1h': 1.06253,
#     'percent_change_24h': 6.64798,
#     'percent_change_7d': 23.7239,
#     'market_cap': 139748017.2492181,
#     'last_updated': '2019-12-04T19:20:08.000Z'}}},
#  {'id': 4030,
#   'name': 'Algorand',
#   'symbol': 'ALGO',
#   'slug': 'algorand',
#   'num_market_pairs': 60,
#   'date_added': '2019-06-20T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 454946250.472551,
#   'total_supply': 2986218093.47255,
#   'platform': None,
#   'cmc_rank': 42,
#   'last_updated': '2019-12-04T19:20:13.000Z',
#   'quote': {'USD': {'price': 0.277783344817,
#     'volume_24h': 127329279.879041,
#     'percent_change_1h': 0.488078,
#     'percent_change_24h': -2.66258,
#     'percent_change_7d': 22.7499,
#     'market_cap': 126376491.16821788,
#     'last_updated': '2019-12-04T19:20:13.000Z'}}},
#  {'id': 2682,
#   'name': 'Holo',
#   'symbol': 'HOT',
#   'slug': 'holo',
#   'num_market_pairs': 62,
#   'date_added': '2018-04-29T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 161496951785.847,
#   'total_supply': 177619433541.141,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x6c6ee5e31d828de241282b9606c8e98ea48526e2'},
#   'cmc_rank': 43,
#   'last_updated': '2019-12-04T19:20:09.000Z',
#   'quote': {'USD': {'price': 0.000779547823206,
#     'volume_24h': 6262056.1854827,
#     'percent_change_1h': 0.387993,
#     'percent_change_24h': -0.340366,
#     'percent_change_7d': -5.76282,
#     'market_cap': 125894597.21906136,
#     'last_updated': '2019-12-04T19:20:09.000Z'}}},
#  {'id': 2830,
#   'name': 'Seele',
#   'symbol': 'SEELE',
#   'slug': 'seele',
#   'num_market_pairs': 14,
#   'date_added': '2018-05-31T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 699562206.289478,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xb1eef147028e9f480dbc5ccaa3277d417d1b85f0'},
#   'cmc_rank': 44,
#   'last_updated': '2019-12-04T19:20:09.000Z',
#   'quote': {'USD': {'price': 0.162666745168,
#     'volume_24h': 52329787.81178,
#     'percent_change_1h': 0.256278,
#     'percent_change_24h': -1.3711,
#     'percent_change_7d': 20.3754,
#     'market_cap': 113795507.13965435,
#     'last_updated': '2019-12-04T19:20:09.000Z'}}},
#  {'id': 1104,
#   'name': 'Augur',
#   'symbol': 'REP',
#   'slug': 'augur',
#   'num_market_pairs': 67,
#   'date_added': '2015-10-27T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 11000000,
#   'total_supply': 11000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x1985365e9f78359a9b6ad760e32412f4a445e862'},
#   'cmc_rank': 45,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': {'USD': {'price': 10.1915857409,
#     'volume_24h': 6559658.17906141,
#     'percent_change_1h': 0.102538,
#     'percent_change_24h': -2.63455,
#     'percent_change_7d': -9.59732,
#     'market_cap': 112107443.1499,
#     'last_updated': '2019-12-04T19:20:04.000Z'}}},
#  {'id': 1567,
#   'name': 'Nano',
#   'symbol': 'NANO',
#   'slug': 'nano',
#   'num_market_pairs': 50,
#   'date_added': '2017-03-06T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 133248297.197,
#   'circulating_supply': 133248297.197,
#   'total_supply': 133248297.197,
#   'platform': None,
#   'cmc_rank': 46,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': {'USD': {'price': 0.828618074768,
#     'volume_24h': 2844723.75339415,
#     'percent_change_1h': 0.202491,
#     'percent_change_24h': -1.74274,
#     'percent_change_7d': -0.0251728,
#     'market_cap': 110411947.48949243,
#     'last_updated': '2019-12-04T19:20:05.000Z'}}},
#  {'id': 2083,
#   'name': 'Bitcoin Gold',
#   'symbol': 'BTG',
#   'slug': 'bitcoin-gold',
#   'num_market_pairs': 84,
#   'date_added': '2017-10-23T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000,
#   'circulating_supply': 17513923.589,
#   'total_supply': 17513923.589,
#   'platform': None,
#   'cmc_rank': 47,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': {'USD': {'price': 6.03249988289,
#     'volume_24h': 12070776.6017658,
#     'percent_change_1h': -0.0752915,
#     'percent_change_24h': -0.151147,
#     'percent_change_7d': -7.27641,
#     'market_cap': 105652741.99958691,
#     'last_updated': '2019-12-04T19:20:07.000Z'}}},
#  {'id': 1808,
#   'name': 'OmiseGO',
#   'symbol': 'OMG',
#   'slug': 'omisego',
#   'num_market_pairs': 203,
#   'date_added': '2017-07-14T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 140245398.245133,
#   'total_supply': 140245398.245133,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xd26114cd6EE289AccF82350c8d8487fedB8A0C07'},
#   'cmc_rank': 48,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': {'USD': {'price': 0.745730205214,
#     'volume_24h': 44079053.8909056,
#     'percent_change_1h': 0.275829,
#     'percent_change_24h': 0.493785,
#     'percent_change_7d': -3.32202,
#     'market_cap': 104585229.6136622,
#     'last_updated': '2019-12-04T19:20:06.000Z'}}},
#  {'id': 3704,
#   'name': 'V Systems',
#   'symbol': 'VSYS',
#   'slug': 'v-systems',
#   'num_market_pairs': 33,
#   'date_added': '2019-03-05T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 1867045420,
#   'total_supply': 3781903884,
#   'platform': None,
#   'cmc_rank': 49,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': {'USD': {'price': 0.0525230956649,
#     'volume_24h': 2512780.75483904,
#     'percent_change_1h': -0.00727877,
#     'percent_change_24h': 2.95388,
#     'percent_change_7d': 1.1671,
#     'market_cap': 98063005.2053734,
#     'last_updated': '2019-12-04T19:20:11.000Z'}}},
#  {'id': 3437,
#   'name': 'ABBC Coin',
#   'symbol': 'ABBC',
#   'slug': 'abbc-coin',
#   'num_market_pairs': 39,
#   'date_added': '2018-10-12T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 556626634.357622,
#   'total_supply': 1004488460.0178,
#   'platform': None,
#   'cmc_rank': 50,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': {'USD': {'price': 0.171901854694,
#     'volume_24h': 43025191.5547906,
#     'percent_change_1h': -0.696058,
#     'percent_change_24h': -0.522622,
#     'percent_change_7d': -6.14225,
#     'market_cap': 95685150.8181542,
#     'last_updated': '2019-12-04T19:20:11.000Z'}}},
#  {'id': 4195,
#   'name': 'FTX Token',
#   'symbol': 'FTT',
#   'slug': 'ftx-token',
#   'num_market_pairs': 13,
#   'date_added': '2019-07-31T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 52288488.9327723,
#   'total_supply': 348160825,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9'},
#   'cmc_rank': 51,
#   'last_updated': '2019-12-04T19:20:13.000Z',
#   'quote': {'USD': {'price': 1.7872169939,
#     'volume_24h': 9509155.20072862,
#     'percent_change_1h': 0.261118,
#     'percent_change_24h': 14.3243,
#     'percent_change_7d': 23.7536,
#     'market_cap': 93450876.00600272,
#     'last_updated': '2019-12-04T19:20:13.000Z'}}},
#  {'id': 3351,
#   'name': 'ZB',
#   'symbol': 'ZB',
#   'slug': 'zb',
#   'num_market_pairs': 10,
#   'date_added': '2018-09-27T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 463288810,
#   'total_supply': 2100000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xbd0793332e9fb844a52a205a233ef27a5b34b927'},
#   'cmc_rank': 52,
#   'last_updated': '2019-12-04T19:20:10.000Z',
#   'quote': {'USD': {'price': 0.194067832533,
#     'volume_24h': 222563068.541323,
#     'percent_change_1h': -0.933237,
#     'percent_change_24h': -1.91655,
#     'percent_change_7d': 0.565066,
#     'market_cap': 89909455.19349286,
#     'last_updated': '2019-12-04T19:20:10.000Z'}}},
#  {'id': 109,
#   'name': 'DigiByte',
#   'symbol': 'DGB',
#   'slug': 'digibyte',
#   'num_market_pairs': 78,
#   'date_added': '2014-02-06T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000000,
#   'circulating_supply': 12563015176.4017,
#   'total_supply': 12563015176.4017,
#   'platform': None,
#   'cmc_rank': 53,
#   'last_updated': '2019-12-04T19:20:02.000Z',
#   'quote': {'USD': {'price': 0.0067475633902,
#     'volume_24h': 1094597.14189187,
#     'percent_change_1h': 0.16436,
#     'percent_change_24h': 0.937312,
#     'percent_change_7d': -2.70832,
#     'market_cap': 84769741.2748151,
#     'last_updated': '2019-12-04T19:20:02.000Z'}}},
#  {'id': 1214,
#   'name': 'Lisk',
#   'symbol': 'LSK',
#   'slug': 'lisk',
#   'num_market_pairs': 61,
#   'date_added': '2016-04-06T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 121841760.912821,
#   'total_supply': 136862662,
#   'platform': None,
#   'cmc_rank': 54,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': {'USD': {'price': 0.676853675379,
#     'volume_24h': 807257.961820839,
#     'percent_change_1h': -0.163754,
#     'percent_change_24h': 0.291738,
#     'percent_change_7d': -1.04831,
#     'market_cap': 82469043.68849227,
#     'last_updated': '2019-12-04T19:20:04.000Z'}}},
#  {'id': 1866,
#   'name': 'Bytom',
#   'symbol': 'BTM',
#   'slug': 'bytom',
#   'num_market_pairs': 50,
#   'date_added': '2017-08-08T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 1002499275,
#   'total_supply': 1407000000,
#   'platform': None,
#   'cmc_rank': 55,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': {'USD': {'price': 0.0803865896344,
#     'volume_24h': 13835133.802472,
#     'percent_change_1h': 0.137345,
#     'percent_change_24h': -0.186574,
#     'percent_change_7d': 8.35608,
#     'market_cap': 80587497.82820852,
#     'last_updated': '2019-12-04T19:20:06.000Z'}}},
#  {'id': 3890,
#   'name': 'Matic Network',
#   'symbol': 'MATIC',
#   'slug': 'matic-network',
#   'num_market_pairs': 31,
#   'date_added': '2019-04-28T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 2539297092,
#   'total_supply': 10000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0'},
#   'cmc_rank': 56,
#   'last_updated': '2019-12-04T19:20:12.000Z',
#   'quote': {'USD': {'price': 0.0317333001531,
#     'volume_24h': 64572872.9835282,
#     'percent_change_1h': -0.237703,
#     'percent_change_24h': 7.80409,
#     'percent_change_7d': 30.239,
#     'market_cap': 80580276.79832998,
#     'last_updated': '2019-12-04T19:20:12.000Z'}}},
#  {'id': 1521,
#   'name': 'Komodo',
#   'symbol': 'KMD',
#   'slug': 'komodo',
#   'num_market_pairs': 23,
#   'date_added': '2017-02-05T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 200000000,
#   'circulating_supply': 117292457.72457,
#   'total_supply': 117292457.72457,
#   'platform': None,
#   'cmc_rank': 57,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': {'USD': {'price': 0.68659541636,
#     'volume_24h': 3567336.22766169,
#     'percent_change_1h': 0.328411,
#     'percent_change_24h': -1.34715,
#     'percent_change_7d': -1.16541,
#     'market_cap': 80532463.84728885,
#     'last_updated': '2019-12-04T19:20:05.000Z'}}},
#  {'id': 2087,
#   'name': 'KuCoin Shares',
#   'symbol': 'KCS',
#   'slug': 'kucoin-shares',
#   'num_market_pairs': 15,
#   'date_added': '2017-10-24T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 82363551,
#   'total_supply': 172363551,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x039b5649a59967e3e936d7471f9c3700100ee1ab'},
#   'cmc_rank': 58,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': {'USD': {'price': 0.969602451256,
#     'volume_24h': 5120671.68399484,
#     'percent_change_1h': -0.0118973,
#     'percent_change_24h': -0.433827,
#     'percent_change_7d': -1.77191,
#     'market_cap': 79859900.94374856,
#     'last_updated': '2019-12-04T19:20:07.000Z'}}},
#  {'id': 2453,
#   'name': 'EDUCare',
#   'symbol': 'EKT',
#   'slug': 'educare',
#   'num_market_pairs': 6,
#   'date_added': '2018-01-23T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 1000000000,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x4ecdb6385f3db3847f9c4a9bf3f9917bb27a5452'},
#   'cmc_rank': 59,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': {'USD': {'price': 0.0777999659233,
#     'volume_24h': 4166585.51794954,
#     'percent_change_1h': -0.0986253,
#     'percent_change_24h': -4.2183,
#     'percent_change_7d': -26.0502,
#     'market_cap': 77799965.9233,
#     'last_updated': '2019-12-04T19:20:07.000Z'}}},
#  {'id': 4172,
#   'name': 'LUNA',
#   'symbol': 'LUNA',
#   'slug': 'luna',
#   'num_market_pairs': 10,
#   'date_added': '2019-07-26T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 287765804.430561,
#   'total_supply': 995859074.224591,
#   'platform': None,
#   'cmc_rank': 60,
#   'last_updated': '2019-12-04T19:20:13.000Z',
#   'quote': {'USD': {'price': 0.252346644175,
#     'volume_24h': 537364.128990684,
#     'percent_change_1h': 0.0101404,
#     'percent_change_24h': -3.00482,
#     'percent_change_7d': 12.871,
#     'market_cap': 72616735.05637142,
#     'last_updated': '2019-12-04T19:20:13.000Z'}}},
#  {'id': 4279,
#   'name': 'Swipe',
#   'symbol': 'SXP',
#   'slug': 'swipe',
#   'num_market_pairs': 9,
#   'date_added': '2019-08-26T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 61135911.166,
#   'total_supply': 300000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x8ce9137d39326ad0cd6491fb5cc0cba0e089b6a9'},
#   'cmc_rank': 61,
#   'last_updated': '2019-12-04T19:20:13.000Z',
#   'quote': {'USD': {'price': 1.15718178827,
#     'volume_24h': 14989360.5471338,
#     'percent_change_1h': 0.370984,
#     'percent_change_24h': -0.508883,
#     'percent_change_7d': -4.15367,
#     'market_cap': 70745363.01058774,
#     'last_updated': '2019-12-04T19:20:13.000Z'}}},
#  {'id': 2405,
#   'name': 'IOST',
#   'symbol': 'IOST',
#   'slug': 'iostoken',
#   'num_market_pairs': 84,
#   'date_added': '2018-01-16T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 12013965608.8475,
#   'total_supply': 21000000000,
#   'platform': None,
#   'cmc_rank': 62,
#   'last_updated': '2019-12-04T19:20:08.000Z',
#   'quote': {'USD': {'price': 0.00577529682436,
#     'volume_24h': 32144044.2047103,
#     'percent_change_1h': 0.425905,
#     'percent_change_24h': -2.92314,
#     'percent_change_7d': 6.3665,
#     'market_cap': 69384217.42874722,
#     'last_updated': '2019-12-04T19:20:08.000Z'}}},
#  {'id': 2222,
#   'name': 'Bitcoin Diamond',
#   'symbol': 'BCD',
#   'slug': 'bitcoin-diamond',
#   'num_market_pairs': 25,
#   'date_added': '2017-11-24T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 210000000,
#   'circulating_supply': 186492897.953,
#   'total_supply': 189492897.953,
#   'platform': None,
#   'cmc_rank': 63,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': {'USD': {'price': 0.368973068371,
#     'volume_24h': 2301329.93761891,
#     'percent_change_1h': 1.01223,
#     'percent_change_24h': -1.09488,
#     'percent_change_7d': -4.48209,
#     'market_cap': 68810856.7871182,
#     'last_updated': '2019-12-04T19:20:07.000Z'}}},
#  {'id': 2099,
#   'name': 'ICON',
#   'symbol': 'ICX',
#   'slug': 'icon',
#   'num_market_pairs': 63,
#   'date_added': '2017-10-27T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 507821713.297343,
#   'total_supply': 800460000,
#   'platform': None,
#   'cmc_rank': 64,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': {'USD': {'price': 0.132662823645,
#     'volume_24h': 4465818.85926384,
#     'percent_change_1h': -0.468136,
#     'percent_change_24h': -0.287762,
#     'percent_change_7d': -3.3032,
#     'market_cap': 67369062.39426717,
#     'last_updated': '2019-12-04T19:20:07.000Z'}}},
#  {'id': 3718,
#   'name': 'BitTorrent',
#   'symbol': 'BTT',
#   'slug': 'bittorrent',
#   'num_market_pairs': 129,
#   'date_added': '2019-01-31T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 212116500000,
#   'total_supply': 990000000000,
#   'platform': {'id': 1958,
#    'name': 'TRON',
#    'symbol': 'TRX',
#    'slug': 'tron',
#    'token_address': '1002000'},
#   'cmc_rank': 65,
#   'last_updated': '2019-12-04T19:20:12.000Z',
#   'quote': {'USD': {'price': 0.000310382519492,
#     'volume_24h': 55327478.5111138,
#     'percent_change_1h': -0.493093,
#     'percent_change_24h': -0.738465,
#     'percent_change_7d': -1.71504,
#     'market_cap': 65837253.69582482,
#     'last_updated': '2019-12-04T19:20:12.000Z'}}},
#  {'id': 2416,
#   'name': 'THETA',
#   'symbol': 'THETA',
#   'slug': 'theta',
#   'num_market_pairs': 30,
#   'date_added': '2018-01-17T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 870502690,
#   'total_supply': 1000000000,
#   'platform': None,
#   'cmc_rank': 66,
#   'last_updated': '2019-12-04T19:20:08.000Z',
#   'quote': {'USD': {'price': 0.0748310023917,
#     'volume_24h': 1498890.74226663,
#     'percent_change_1h': 0.324021,
#     'percent_change_24h': -3.91241,
#     'percent_change_7d': -3.70323,
#     'market_cap': 65140588.87737128,
#     'last_updated': '2019-12-04T19:20:08.000Z'}}},
#  {'id': 1042,
#   'name': 'Siacoin',
#   'symbol': 'SC',
#   'slug': 'siacoin',
#   'num_market_pairs': 38,
#   'date_added': '2015-08-26T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 41817047634,
#   'total_supply': 41817047634,
#   'platform': None,
#   'cmc_rank': 67,
#   'last_updated': '2019-12-04T19:20:03.000Z',
#   'quote': {'USD': {'price': 0.00153945994764,
#     'volume_24h': 1655624.7394915,
#     'percent_change_1h': 0.564038,
#     'percent_change_24h': -1.64881,
#     'percent_change_7d': -2.80527,
#     'market_cap': 64375669.96109703,
#     'last_updated': '2019-12-04T19:20:03.000Z'}}},
#  {'id': 1776,
#   'name': 'MCO',
#   'symbol': 'MCO',
#   'slug': 'crypto-com',
#   'num_market_pairs': 57,
#   'date_added': '2017-07-03T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 15793831.0949625,
#   'total_supply': 31587682.3632061,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xb63b606ac810a52cca15e44bb630fd42d8d1d83d'},
#   'cmc_rank': 68,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': {'USD': {'price': 4.05082133536,
#     'volume_24h': 14796280.5645534,
#     'percent_change_1h': 0.272637,
#     'percent_change_24h': 2.30277,
#     'percent_change_7d': 1.6761,
#     'market_cap': 63977987.96654629,
#     'last_updated': '2019-12-04T19:20:05.000Z'}}},
#  {'id': 693,
#   'name': 'Verge',
#   'symbol': 'XVG',
#   'slug': 'verge',
#   'num_market_pairs': 59,
#   'date_added': '2014-10-25T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 16555000000,
#   'circulating_supply': 16087657429.1206,
#   'total_supply': 16087657429.1206,
#   'platform': None,
#   'cmc_rank': 69,
#   'last_updated': '2019-12-04T19:20:03.000Z',
#   'quote': {'USD': {'price': 0.00397596096925,
#     'volume_24h': 2645406.82010612,
#     'percent_change_1h': 0.423353,
#     'percent_change_24h': 2.20022,
#     'percent_change_7d': -0.676118,
#     'market_cap': 63963898.024848305,
#     'last_updated': '2019-12-04T19:20:03.000Z'}}},
#  {'id': 2441,
#   'name': 'Molecular Future',
#   'symbol': 'MOF',
#   'slug': 'molecular-future',
#   'num_market_pairs': 11,
#   'date_added': '2018-01-20T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 43842875.0687909,
#   'total_supply': 100000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x653430560be843c4a3d143d0110e896c2ab8ac0d'},
#   'cmc_rank': 70,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': {'USD': {'price': 1.44120773366,
#     'volume_24h': 33826231.8864744,
#     'percent_change_1h': 1.01201,
#     'percent_change_24h': -2.49396,
#     'percent_change_7d': 30.5369,
#     'market_cap': 63186690.61503065,
#     'last_updated': '2019-12-04T19:20:07.000Z'}}},
#  {'id': 3155,
#   'name': 'Quant',
#   'symbol': 'QNT',
#   'slug': 'quant',
#   'num_market_pairs': 18,
#   'date_added': '2018-08-10T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 12072738,
#   'total_supply': 14612493.0808262,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x4a220e6096b25eadb88358cb44068a3248254675'},
#   'cmc_rank': 71,
#   'last_updated': '2019-12-04T19:20:10.000Z',
#   'quote': {'USD': {'price': 5.08763514139,
#     'volume_24h': 3066195.71720615,
#     'percent_change_1h': 0.302806,
#     'percent_change_24h': -7.34354,
#     'percent_change_7d': -15.4467,
#     'market_cap': 61421686.101594426,
#     'last_updated': '2019-12-04T19:20:10.000Z'}}},
#  {'id': 2130,
#   'name': 'Enjin Coin',
#   'symbol': 'ENJ',
#   'slug': 'enjin-coin',
#   'num_market_pairs': 52,
#   'date_added': '2017-11-01T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
# ...
#   'date_added': '2014-07-21T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 3600570502,
#   'circulating_supply': 2748920000,
#   'total_supply': 2748920000,
#   'platform': None,
#   'cmc_rank': 78,
#   'last_updated': '2019-12-04T19:20:03.000Z',
#   'quote': {'USD': {'price': 0.0204996806242,
#     'volume_24h': 1453065.56194915,
#     'percent_change_1h': 0.951275,
#     'percent_change_24h': 0.579625,
#     'percent_change_7d': -4.13522,
#     'market_cap': 56351982.061475866,
#     'last_updated': '2019-12-04T19:20:03.000Z'}}},
#  {'id': 2469,
#   'name': 'Zilliqa',
#   'symbol': 'ZIL',
#   'slug': 'zilliqa',
#   'num_market_pairs': 104,
#   'date_added': '2018-01-25T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 9729027774.34355,
#   'total_supply': 13020494927.3436,
#   'platform': None,
#   'cmc_rank': 79,
#   'last_updated': '2019-12-04T19:20:08.000Z',
#   'quote': {'USD': {'price': 0.00568495791831,
#     'volume_24h': 12451386.7191739,
#     'percent_change_1h': 0.0731521,
#     'percent_change_24h': 1.72542,
#     'percent_change_7d': 9.7349,
#     'market_cap': 55309113.48321228,
#     'last_updated': '2019-12-04T19:20:08.000Z'}}},
#  {'id': 291,
#   'name': 'MaidSafeCoin',
#   'symbol': 'MAID',
#   'slug': 'maidsafecoin',
#   'num_market_pairs': 6,
#   'date_added': '2014-04-28T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 452552412,
#   'total_supply': 452552412,
#   'platform': {'id': 83,
#    'name': 'Omni',
#    'symbol': 'OMNI',
#    'slug': 'omni',
#    'token_address': '3'},
#   'cmc_rank': 80,
#   'last_updated': '2019-12-04T19:20:02.000Z',
#   'quote': {'USD': {'price': 0.121800823696,
#     'volume_24h': 265933.206573776,
#     'percent_change_1h': 0.847663,
#     'percent_change_24h': -2.38882,
#     'percent_change_7d': 4.99796,
#     'market_cap': 55121256.54721155,
#     'last_updated': '2019-12-04T19:20:02.000Z'}}},
#  {'id': 1903,
#   'name': 'HyperCash',
#   'symbol': 'HC',
#   'slug': 'hypercash',
#   'num_market_pairs': 32,
#   'date_added': '2017-08-20T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 84000000,
#   'circulating_supply': 44445722.337052,
#   'total_supply': 44445722.337052,
#   'platform': None,
#   'cmc_rank': 81,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': {'USD': {'price': 1.23194151213,
#     'volume_24h': 2512937.60669013,
#     'percent_change_1h': 0.0390178,
#     'percent_change_24h': 0.177333,
#     'percent_change_7d': 3.0972,
#     'market_cap': 54754530.38361796,
#     'last_updated': '2019-12-04T19:20:06.000Z'}}},
#  {'id': 2694,
#   'name': 'Nexo',
#   'symbol': 'NEXO',
#   'slug': 'nexo',
#   'num_market_pairs': 21,
#   'date_added': '2018-05-01T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 560000011,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xb62132e35a6c13ee1ee0f84dc5d40bad8d815206'},
#   'cmc_rank': 82,
#   'last_updated': '2019-12-04T19:20:09.000Z',
#   'quote': {'USD': {'price': 0.096044291962,
#     'volume_24h': 8830190.82097838,
#     'percent_change_1h': 0.230553,
#     'percent_change_24h': 2.44351,
#     'percent_change_7d': 1.94256,
#     'market_cap': 53784804.55520721,
#     'last_updated': '2019-12-04T19:20:09.000Z'}}},
#  {'id': 1320,
#   'name': 'Ardor',
#   'symbol': 'ARDR',
#   'slug': 'ardor',
#   'num_market_pairs': 26,
#   'date_added': '2016-07-23T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 998999495,
#   'circulating_supply': 998999495,
#   'total_supply': 998999495,
#   'platform': None,
#   'cmc_rank': 83,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': {'USD': {'price': 0.0485927208447,
#     'volume_24h': 2130696.60545705,
#     'percent_change_1h': -0.373775,
#     'percent_change_24h': -1.54058,
#     'percent_change_7d': -6.9064,
#     'market_cap': 48544103.58453128,
#     'last_updated': '2019-12-04T19:20:04.000Z'}}},
#  {'id': 1700,
#   'name': 'Aeternity',
#   'symbol': 'AE',
#   'slug': 'aeternity',
#   'num_market_pairs': 51,
#   'date_added': '2017-06-01T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 293276971.5,
#   'total_supply': 339097915.49932,
#   'platform': None,
#   'cmc_rank': 84,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': {'USD': {'price': 0.160113370096,
#     'volume_24h': 30535634.5502999,
#     'percent_change_1h': -0.580197,
#     'percent_change_24h': 0.0638441,
#     'percent_change_7d': -0.246796,
#     'market_cap': 46957564.27841354,
#     'last_updated': '2019-12-04T19:20:05.000Z'}}},
#  {'id': 1637,
#   'name': 'iExec RLC',
#   'symbol': 'RLC',
#   'slug': 'rlc',
#   'num_market_pairs': 17,
#   'date_added': '2017-04-20T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 80070793.2387674,
#   'total_supply': 86999784.9868455,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x607f4c5bb672230e8672085532f7e901544a7375'},
#   'cmc_rank': 85,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': {'USD': {'price': 0.553042304351,
#     'volume_24h': 916204.600494181,
#     'percent_change_1h': -1.55225,
#     'percent_change_24h': -0.39232,
#     'percent_change_7d': -14.1137,
#     'market_cap': 44282536.00398039,
#     'last_updated': '2019-12-04T19:20:05.000Z'}}},
#  {'id': 1230,
#   'name': 'Steem',
#   'symbol': 'STEEM',
#   'slug': 'steem',
#   'num_market_pairs': 33,
#   'date_added': '2016-04-18T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 353003191.076,
#   'total_supply': 369977285.076,
#   'platform': None,
#   'cmc_rank': 86,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': {'USD': {'price': 0.123210417556,
#     'volume_24h': 506667.397555674,
#     'percent_change_1h': 0.809919,
#     'percent_change_24h': 1.81401,
#     'percent_change_7d': -10.6302,
#     'market_cap': 43493670.57107441,
#     'last_updated': '2019-12-04T19:20:04.000Z'}}},
#  {'id': 1698,
#   'name': 'Horizen',
#   'symbol': 'ZEN',
#   'slug': 'horizen',
#   'num_market_pairs': 34,
#   'date_added': '2017-06-01T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000,
#   'circulating_supply': 7906087.5,
#   'total_supply': 7906087.5,
#   'platform': None,
#   'cmc_rank': 87,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': {'USD': {'price': 5.20400397603,
#     'volume_24h': 559508.039321173,
#     'percent_change_1h': -0.100621,
#     'percent_change_24h': -2.72595,
#     'percent_change_7d': -7.82462,
#     'market_cap': 41143310.78484108,
#     'last_updated': '2019-12-04T19:20:05.000Z'}}},
#  {'id': 4066,
#   'name': 'Chiliz',
#   'symbol': 'CHZ',
#   'slug': 'chiliz',
#   'num_market_pairs': 10,
#   'date_added': '2019-07-01T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 3763769182,
#   'total_supply': 8888888888,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x3506424f91fd33084466f402d5d97f05f8e3b4af'},
#   'cmc_rank': 88,
#   'last_updated': '2019-12-04T19:20:12.000Z',
#   'quote': {'USD': {'price': 0.0107356003814,
#     'volume_24h': 3638075.21711364,
#     'percent_change_1h': -0.599885,
#     'percent_change_24h': -4.18964,
#     'percent_change_7d': -12.5893,
#     'market_cap': 40406321.86578076,
#     'last_updated': '2019-12-04T19:20:12.000Z'}}},
#  {'id': 3724,
#   'name': 'SOLVE',
#   'symbol': 'SOLVE',
#   'slug': 'solve',
#   'num_market_pairs': 9,
#   'date_added': '2019-02-04T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 1000000000,
#   'circulating_supply': 327424138.235688,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x446c9033e7516d820cc9a2ce2d0b7328b579406f'},
#   'cmc_rank': 89,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': {'USD': {'price': 0.120966375666,
#     'volume_24h': 1309028.5168065,
#     'percent_change_1h': 0.208379,
#     'percent_change_24h': -0.662519,
#     'percent_change_7d': 2.14578,
#     'market_cap': 39607311.307934545,
#     'last_updated': '2019-12-04T19:20:11.000Z'}}},
#  {'id': 3773,
#   'name': 'Fetch.ai',
#   'symbol': 'FET',
#   'slug': 'fetch',
#   'num_market_pairs': 28,
#   'date_added': '2019-03-02T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 1152997575,
#   'circulating_supply': 654717118.965709,
#   'total_supply': 1152997575,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x1d287cc25dad7ccaf76a26bc660c5f7c8e2a05bd'},
#   'cmc_rank': 90,
#   'last_updated': '2019-12-04T19:20:12.000Z',
#   'quote': {'USD': {'price': 0.0592446080423,
#     'volume_24h': 22061302.6657402,
#     'percent_change_1h': -0.142911,
#     'percent_change_24h': -2.15401,
#     'percent_change_7d': 14.5961,
#     'market_cap': 38788459.09170733,
#     'last_updated': '2019-12-04T19:20:12.000Z'}}},
#  {'id': 2137,
#   'name': 'Electroneum',
#   'symbol': 'ETN',
#   'slug': 'electroneum',
#   'num_market_pairs': 20,
#   'date_added': '2017-11-02T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000000,
#   'circulating_supply': 9909722400.95,
#   'total_supply': 9909722400.95,
#   'platform': None,
#   'cmc_rank': 91,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': {'USD': {'price': 0.00384062345667,
#     'volume_24h': 168584.090319802,
#     'percent_change_1h': 0.216667,
#     'percent_change_24h': 0.619848,
#     'percent_change_7d': 7.78954,
#     'market_cap': 38059512.30217672,
#     'last_updated': '2019-12-04T19:20:07.000Z'}}},
#  {'id': 1759,
#   'name': 'Status',
#   'symbol': 'SNT',
#   'slug': 'status',
#   'num_market_pairs': 86,
#   'date_added': '2017-06-28T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 3470483788,
#   'total_supply': 6804870174,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x744d70fdbe2ba4cf95131626614a1763df805b9e'},
#   'cmc_rank': 92,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': {'USD': {'price': 0.0109434172715,
#     'volume_24h': 181315426.422291,
#     'percent_change_1h': 0.145766,
#     'percent_change_24h': -0.0627233,
#     'percent_change_7d': 1.44458,
#     'market_cap': 37978952.22605994,
#     'last_updated': '2019-12-04T19:20:05.000Z'}}},
#  {'id': 2603,
#   'name': 'Pundi X',
#   'symbol': 'NPXS',
#   'slug': 'pundi-x',
#   'num_market_pairs': 69,
#   'date_added': '2018-03-22T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 234562817276.377,
#   'total_supply': 259810708832.63,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa15c7ebe1f07caf6bff097d8a589fb8ac49ae5b3'},
#   'cmc_rank': 93,
#   'last_updated': '2019-12-04T19:20:08.000Z',
#   'quote': {'USD': {'price': 0.000158686058166,
#     'volume_24h': 837062.569655854,
#     'percent_change_1h': 0.185136,
#     'percent_change_24h': 0.0230475,
#     'percent_change_7d': 5.04723,
#     'market_cap': 37221848.86589999,
#     'last_updated': '2019-12-04T19:20:08.000Z'}}},
#  {'id': 2044,
#   'name': 'Enigma',
#   'symbol': 'ENG',
#   'slug': 'enigma',
#   'num_market_pairs': 27,
#   'date_added': '2017-10-13T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 74836171.09,
#   'total_supply': 150000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xf0ee6b27b759c9893ce4f094b49ad28fd15a23e4'},
#   'cmc_rank': 94,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': {'USD': {'price': 0.491622538251,
#     'volume_24h': 1053281.45722912,
#     'percent_change_1h': 1.74872,
#     'percent_change_24h': 3.7691,
#     'percent_change_7d': -10.2528,
#     'market_cap': 36791148.38425191,
#     'last_updated': '2019-12-04T19:20:07.000Z'}}},
#  {'id': 1455,
#   'name': 'Golem',
#   'symbol': 'GNT',
#   'slug': 'golem-network-tokens',
#   'num_market_pairs': 98,
#   'date_added': '2016-11-18T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 980050000,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa74476443119A942dE498590Fe1f2454d7D4aC0d'},
#   'cmc_rank': 95,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': {'USD': {'price': 0.0371818484854,
#     'volume_24h': 1916242.74580089,
#     'percent_change_1h': 0.5995,
#     'percent_change_24h': -2.47337,
#     'percent_change_7d': -1.28387,
#     'market_cap': 36440070.60811627,
#     'last_updated': '2019-12-04T19:20:05.000Z'}}},
#  {'id': 3617,
#   'name': 'ILCoin',
#   'symbol': 'ILC',
#   'slug': 'ilcoin',
#   'num_market_pairs': 26,
#   'date_added': '2018-11-26T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 2500000000,
#   'circulating_supply': 345442487.370894,
#   'total_supply': 1299138907.43547,
#   'platform': None,
#   'cmc_rank': 96,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': {'USD': {'price': 0.104835414715,
#     'volume_24h': 521359.395891948,
#     'percent_change_1h': -0.361615,
#     'percent_change_24h': -0.741058,
#     'percent_change_7d': 7.37294,
#     'market_cap': 36214606.42370883,
#     'last_updated': '2019-12-04T19:20:11.000Z'}}},
#  {'id': 2447,
#   'name': 'Crypterium',
#   'symbol': 'CRPT',
#   'slug': 'crpt',
#   'num_market_pairs': 9,
#   'date_added': '2018-01-22T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 84759818.6100001,
#   'total_supply': 99757369.7528572,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x80a7e048f37a50500351c204cb407766fa3bae7f'},
#   'cmc_rank': 97,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': {'USD': {'price': 0.4256168924,
#     'volume_24h': 321292.722285399,
#     'percent_change_1h': 0.0406616,
#     'percent_change_24h': -2.00103,
#     'percent_change_7d': -6.10492,
#     'market_cap': 36075210.59717593,
#     'last_updated': '2019-12-04T19:20:07.000Z'}}},
#  {'id': 2772,
#   'name': 'Digitex Futures',
#   'symbol': 'DGTX',
#   'slug': 'digitex-futures',
#   'num_market_pairs': 7,
#   'date_added': '2018-05-23T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 786260027.490069,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x1c83501478f1320977047008496dacbd60bb15ef'},
#   'cmc_rank': 98,
#   'last_updated': '2019-12-04T19:20:09.000Z',
#   'quote': {'USD': {'price': 0.0457448373776,
#     'volume_24h': 1139158.5434491,
#     'percent_change_1h': 1.0011,
#     'percent_change_24h': -2.45898,
#     'percent_change_7d': -9.28453,
#     'market_cap': 35967337.09404051,
#     'last_updated': '2019-12-04T19:20:09.000Z'}}},
#  {'id': 1229,
#   'name': 'DigixDAO',
#   'symbol': 'DGD',
#   'slug': 'digixdao',
#   'num_market_pairs': 27,
#   'date_added': '2016-04-18T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 2000000,
#   'total_supply': 2000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xe0b7927c4af23765cb51314a0e0521a9645f0e2a'},
#   'cmc_rank': 99,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': {'USD': {'price': 17.9545732963,
#     'volume_24h': 623738.309920964,
#     'percent_change_1h': 0.170762,
#     'percent_change_24h': -1.58981,
#     'percent_change_7d': 32.3195,
#     'market_cap': 35909146.5926,
#     'last_updated': '2019-12-04T19:20:04.000Z'}}},
#  {'id': 2989,
#   'name': 'STASIS EURO',
#   'symbol': 'EURS',
#   'slug': 'stasis-euro',
#   'num_market_pairs': 29,
#   'date_added': '2018-07-30T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 31979207,
#   'total_supply': 31979207,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xdb25f211ab05b1c97d595516f45794528a807ad8'},
#   'cmc_rank': 100,
#   'last_updated': '2019-12-04T19:20:10.000Z',
#   'quote': {'USD': {'price': 1.10183737053,
#     'volume_24h': 792056.350151364,
#     'percent_change_1h': -0.0085851,
#     'percent_change_24h': 0.100467,
#     'percent_change_7d': 0.262636,
#     'market_cap': 35235885.35251457,
#     'last_updated': '2019-12-04T19:20:10.000Z'}}}]

# %%
url = "https://pro-api.coinmarketcap.com/v1/blockchain/statistics/latest"
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '8156fd5c-1e27-4c73-8393-fef3b616fe8d',
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    consensus_data = json.loads(response.text)
#     print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
# Out:
# {'status': {'timestamp': '2019-12-04T16:37:06.757Z', 'error_code': 0, 'error_message': None, 'elapsed': 15, 'credit_count': 1, 'notice': None}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 7719, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18083012, 'total_supply': 18083012, 'platform': None, 'cmc_rank': 1, 'last_updated': '2019-12-04T16:36:39.000Z', 'quote': {'USD': {'price': 7473.33358131, 'volume_24h': 19359325961.0166, 'percent_change_1h': -0.209582, 'percent_change_24h': 1.36571, 'percent_change_7d': 1.31537, 'market_cap': 135140380830.83171, 'last_updated': '2019-12-04T16:36:39.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 5336, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': None, 'circulating_supply': 108796454.749, 'total_supply': 108796454.749, 'platform': None, 'cmc_rank': 2, 'last_updated': '2019-12-04T16:36:23.000Z', 'quote': {'USD': {'price': 149.574425867, 'volume_24h': 7441687171.12115, 'percent_change_1h': -0.102632, 'percent_change_24h': 0.243996, 'percent_change_7d': -0.746315, 'market_cap': 16273167255.44672, 'last_updated': '2019-12-04T16:36:23.000Z'}}}, {'id': 52, 'name': 'XRP', 'symbol': 'XRP', 'slug': 'xrp', 'num_market_pairs': 508, 'date_added': '2013-08-04T00:00:00.000Z', 'tags': [], 'max_supply': 100000000000, 'circulating_supply': 43285660917, 'total_supply': 99991237614, 'platform': None, 'cmc_rank': 3, 'last_updated': '2019-12-04T16:36:06.000Z', 'quote': {'USD': {'price': 0.220124015908, 'volume_24h': 1339776344.04373, 'percent_change_1h': -0.144137, 'percent_change_24h': -0.631323, 'percent_change_7d': -1.33052, 'market_cap': 9528213512.282001, 'last_updated': '2019-12-04T16:36:06.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 3927, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': [], 'max_supply': None, 'circulating_supply': 4108044456.1, 'total_supply': 4207771504.46, 'platform': {'id': 83, 'name': 'Omni', 'symbol': 'OMNI', 'slug': 'omni', 'token_address': '31'}, 'cmc_rank': 4, 'last_updated': '2019-12-04T16:36:21.000Z', 'quote': {'USD': {'price': 1.00117825419, 'volume_24h': 22037500478.6887, 'percent_change_1h': -0.344664, 'percent_change_24h': -0.441049, 'percent_change_7d': -0.202884, 'market_cap': 4112884776.693106, 'last_updated': '2019-12-04T16:36:21.000Z'}}}, {'id': 1831, 'name': 'Bitcoin Cash', 'symbol': 'BCH', 'slug': 'bitcoin-cash', 'num_market_pairs': 440, 'date_added': '2017-07-23T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18148537.5, 'total_supply': 18148537.5, 'platform': None, 'cmc_rank': 5, 'last_updated': '2019-12-04T16:36:08.000Z', 'quote': {'USD': {'price': 214.724863297, 'volume_24h': 1405778696.8401, 'percent_change_1h': -0.361312, 'percent_change_24h': -0.158719, 'percent_change_7d': -1.00116, 'market_cap': 3896942233.727978, 'last_updated': '2019-12-04T16:36:08.000Z'}}}, {'id': 2, 'name': 'Litecoin', 'symbol': 'LTC', 'slug': 'litecoin', 'num_market_pairs': 557, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 84000000, 'circulating_supply': 63769119.2668217, 'total_supply': 63769119.2668217, 'platform': None, 'cmc_rank': 6, 'last_updated': '2019-12-04T16:36:06.000Z', 'quote': {'USD': {'price': 46.0341032287, 'volume_24h': 2864643850.02982, 'percent_change_1h': -0.227453, 'percent_change_24h': -0.583959, 'percent_change_7d': -2.96373, 'market_cap': 2935554219.132152, 'last_updated': '2019-12-04T16:36:06.000Z'}}}, {'id': 1765, 'name': 'EOS', 'symbol': 'EOS', 'slug': 'eos', 'num_market_pairs': 394, 'date_added': '2017-07-01T00:00:00.000Z', 'tags': [], 'max_supply': None, 'circulating_supply': 942932350.6709, 'total_supply': 1039632362.163, 'platform': None, 'cmc_rank': 7, 'last_updated': '2019-12-04T16:36:07.000Z', 'quote': {'USD': {'price': 2.69730896384, 'volu ...

# %%
for coin in data:
    coin['quote']= coin['quote'] ['USD']['market_cap']

# %%
data['qupt']
# Out:
# [{'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'slug': 'bitcoin',
#   'num_market_pairs': 7719,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000,
#   'circulating_supply': 18083175,
#   'total_supply': 18083175,
#   'platform': None,
#   'cmc_rank': 1,
#   'last_updated': '2019-12-04T19:20:35.000Z',
#   'quote': 135302589206.78381},
#  {'id': 1027,
#   'name': 'Ethereum',
#   'symbol': 'ETH',
#   'slug': 'ethereum',
#   'num_market_pairs': 5335,
#   'date_added': '2015-08-07T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 108797734.1865,
#   'total_supply': 108797734.1865,
#   'platform': None,
#   'cmc_rank': 2,
#   'last_updated': '2019-12-04T19:20:23.000Z',
#   'quote': 16310931946.598654},
#  {'id': 52,
#   'name': 'XRP',
#   'symbol': 'XRP',
#   'slug': 'xrp',
#   'num_market_pairs': 508,
#   'date_added': '2013-08-04T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 100000000000,
#   'circulating_supply': 43285660917,
#   'total_supply': 99991237614,
#   'platform': None,
#   'cmc_rank': 3,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': 9521243489.680065},
#  {'id': 825,
#   'name': 'Tether',
#   'symbol': 'USDT',
#   'slug': 'tether',
#   'num_market_pairs': 3926,
#   'date_added': '2015-02-25T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 4108044456.1,
#   'total_supply': 4207771504.46,
#   'platform': {'id': 83,
#    'name': 'Omni',
#    'symbol': 'OMNI',
#    'slug': 'omni',
#    'token_address': '31'},
#   'cmc_rank': 4,
#   'last_updated': '2019-12-04T19:20:20.000Z',
#   'quote': 4112977884.28829},
#  {'id': 1831,
#   'name': 'Bitcoin Cash',
#   'symbol': 'BCH',
#   'slug': 'bitcoin-cash',
#   'num_market_pairs': 440,
#   'date_added': '2017-07-23T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000,
#   'circulating_supply': 18148862.5,
#   'total_supply': 18148862.5,
#   'platform': None,
#   'cmc_rank': 5,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': 3870456808.9621844},
#  {'id': 2,
#   'name': 'Litecoin',
#   'symbol': 'LTC',
#   'slug': 'litecoin',
#   'num_market_pairs': 557,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 84000000,
#   'circulating_supply': 63769621.4851745,
#   'total_supply': 63769621.4851745,
#   'platform': None,
#   'cmc_rank': 6,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': 2930375104.8065143},
#  {'id': 1765,
#   'name': 'EOS',
#   'symbol': 'EOS',
#   'slug': 'eos',
#   'num_market_pairs': 394,
#   'date_added': '2017-07-01T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 942947039.0316,
#   'total_supply': 1039647050.5237,
#   'platform': None,
#   'cmc_rank': 7,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': 2532452572.6190896},
#  {'id': 1839,
#   'name': 'Binance Coin',
#   'symbol': 'BNB',
#   'slug': 'binance-coin',
#   'num_market_pairs': 283,
#   'date_added': '2017-07-25T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 187536713,
#   'circulating_supply': 155536713,
#   'total_supply': 187536713,
#   'platform': None,
#   'cmc_rank': 8,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': 2421241044.14365},
#  {'id': 3602,
#   'name': 'Bitcoin SV',
#   'symbol': 'BSV',
#   'slug': 'bitcoin-sv',
#   'num_market_pairs': 154,
#   'date_added': '2018-11-09T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000,
#   'circulating_supply': 18068415,
#   'total_supply': 18068415,
#   'platform': None,
#   'cmc_rank': 9,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': 1744307163.109547},
#  {'id': 512,
#   'name': 'Stellar',
#   'symbol': 'XLM',
#   'slug': 'stellar',
#   'num_market_pairs': 306,
#   'date_added': '2014-08-05T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 20054779553.7,
#   'total_supply': 50000000000,
#   'platform': None,
#   'cmc_rank': 10,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': 1127775511.8581948},
#  {'id': 2010,
#   'name': 'Cardano',
#   'symbol': 'ADA',
#   'slug': 'cardano',
#   'num_market_pairs': 118,
#   'date_added': '2017-10-01T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 45000000000,
#   'circulating_supply': 25927070538,
#   'total_supply': 31112483745,
#   'platform': None,
#   'cmc_rank': 11,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': 989918095.2067538},
#  {'id': 1958,
#   'name': 'TRON',
#   'symbol': 'TRX',
#   'slug': 'tron',
#   'num_market_pairs': 300,
#   'date_added': '2017-09-13T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 66682072191.4,
#   'total_supply': 99281283754.3,
#   'platform': None,
#   'cmc_rank': 12,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': 981789205.1868472},
#  {'id': 328,
#   'name': 'Monero',
#   'symbol': 'XMR',
#   'slug': 'monero',
#   'num_market_pairs': 129,
#   'date_added': '2014-05-21T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 17339143.656908,
#   'total_supply': 17339143.656908,
#   'platform': None,
#   'cmc_rank': 13,
#   'last_updated': '2019-12-04T19:20:03.000Z',
#   'quote': 942560170.6659065},
#  {'id': 3957,
#   'name': 'UNUS SED LEO',
#   'symbol': 'LEO',
#   'slug': 'unus-sed-leo',
#   'num_market_pairs': 26,
#   'date_added': '2019-05-21T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 999498892.9,
#   'total_supply': 999498892.9,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3'},
#   'cmc_rank': 14,
#   'last_updated': '2019-12-04T19:20:12.000Z',
#   'quote': 919684237.3597481},
#  {'id': 2011,
#   'name': 'Tezos',
#   'symbol': 'XTZ',
#   'slug': 'tezos',
#   'num_market_pairs': 55,
#   'date_added': '2017-10-02T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 660373611.97278,
#   'total_supply': 801312599.488106,
#   'platform': None,
#   'cmc_rank': 15,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': 851287450.1035832},
#  {'id': 1975,
#   'name': 'Chainlink',
#   'symbol': 'LINK',
#   'slug': 'chainlink',
#   'num_market_pairs': 120,
#   'date_added': '2017-09-20T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 350000000,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#   'cmc_rank': 16,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': 731083186.344},
#  {'id': 3794,
#   'name': 'Cosmos',
#   'symbol': 'ATOM',
#   'slug': 'cosmos',
#   'num_market_pairs': 99,
#   'date_added': '2019-03-14T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 190688439.2,
#   'total_supply': 237928230.821588,
#   'platform': None,
#   'cmc_rank': 17,
#   'last_updated': '2019-12-04T19:20:12.000Z',
#   'quote': 700500024.3750447},
#  {'id': 2502,
#   'name': 'Huobi Token',
#   'symbol': 'HT',
#   'slug': 'huobi-token',
#   'num_market_pairs': 128,
#   'date_added': '2018-02-03T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 241284046.971921,
#   'total_supply': 500000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x6f259637dcd74c767781e37bc6133cd6a68aa161'},
#   'cmc_rank': 18,
#   'last_updated': '2019-12-04T19:20:09.000Z',
#   'quote': 697978576.6547889},
#  {'id': 1376,
#   'name': 'NEO',
#   'symbol': 'NEO',
#   'slug': 'neo',
#   'num_market_pairs': 226,
#   'date_added': '2016-09-08T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 100000000,
#   'circulating_supply': 70538831,
#   'total_supply': 100000000,
#   'platform': None,
#   'cmc_rank': 19,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': 632584658.3974025},
#  {'id': 1720,
#   'name': 'IOTA',
#   'symbol': 'MIOTA',
#   'slug': 'iota',
#   'num_market_pairs': 48,
#   'date_added': '2017-06-13T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 2779530283,
#   'circulating_supply': 2779530283,
#   'total_supply': 2779530283,
#   'platform': None,
#   'cmc_rank': 20,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': 565223595.0739295},
#  {'id': 1518,
#   'name': 'Maker',
#   'symbol': 'MKR',
#   'slug': 'maker',
#   'num_market_pairs': 70,
#   'date_added': '2017-01-29T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 1000000,
#   'total_supply': 1000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2'},
#   'cmc_rank': 21,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': 553309127.7570001},
#  {'id': 131,
#   'name': 'Dash',
#   'symbol': 'DASH',
#   'slug': 'dash',
#   'num_market_pairs': 271,
#   'date_added': '2014-02-14T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 18900000,
#   'circulating_supply': 9193090.33231986,
#   'total_supply': 9193090.33231986,
#   'platform': None,
#   'cmc_rank': 22,
#   'last_updated': '2019-12-04T19:20:03.000Z',
#   'quote': 474612556.84387934},
#  {'id': 3408,
#   'name': 'USD Coin',
#   'symbol': 'USDC',
#   'slug': 'usd-coin',
#   'num_market_pairs': 182,
#   'date_added': '2018-10-08T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 462767535.369803,
#   'total_supply': 465405615.55,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   'cmc_rank': 23,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': 463219150.1196446},
#  {'id': 1321,
#   'name': 'Ethereum Classic',
#   'symbol': 'ETC',
#   'slug': 'ethereum-classic',
#   'num_market_pairs': 220,
#   'date_added': '2016-07-24T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 210000000,
#   'circulating_supply': 115607209,
#   'total_supply': 115607209,
#   'platform': None,
#   'cmc_rank': 24,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': 442363941.44270104},
#  {'id': 3077,
#   'name': 'VeChain',
#   'symbol': 'VET',
#   'slug': 'vechain',
#   'num_market_pairs': 85,
#   'date_added': '2017-08-22T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 55454734800,
#   'total_supply': 86712634466,
#   'platform': None,
#   'cmc_rank': 25,
#   'last_updated': '2019-12-04T19:20:10.000Z',
#   'quote': 404468059.17816216},
#  {'id': 2566,
#   'name': 'Ontology',
#   'symbol': 'ONT',
#   'slug': 'ontology',
#   'num_market_pairs': 106,
#   'date_added': '2018-03-08T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 637351170,
#   'total_supply': 1000000000,
#   'platform': None,
#   'cmc_rank': 26,
#   'last_updated': '2019-12-04T19:20:09.000Z',
#   'quote': 390638346.92178494},
#  {'id': 873,
#   'name': 'NEM',
#   'symbol': 'XEM',
#   'slug': 'nem',
#   'num_market_pairs': 96,
#   'date_added': '2015-04-01T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 8999999999,
#   'total_supply': 8999999999,
#   'platform': None,
#   'cmc_rank': 27,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': 326064881.0733706},
#  {'id': 3635,
#   'name': 'Crypto.com Coin',
#   'symbol': 'CRO',
#   'slug': 'crypto-com-coin',
#   'num_market_pairs': 38,
#   'date_added': '2018-12-14T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 12105022831.0502,
#   'total_supply': 100000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#   'cmc_rank': 28,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': 324190251.66421336},
#  {'id': 74,
#   'name': 'Dogecoin',
#   'symbol': 'DOGE',
#   'slug': 'dogecoin',
#   'num_market_pairs': 287,
#   'date_added': '2013-12-15T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 122327110779.95,
#   'total_supply': 122327110779.95,
#   'platform': None,
#   'cmc_rank': 29,
#   'last_updated': '2019-12-04T19:20:03.000Z',
#   'quote': 271647861.6625726},
#  {'id': 1697,
#   'name': 'Basic Attention Token',
#   'symbol': 'BAT',
#   'slug': 'basic-attention-token',
#   'num_market_pairs': 161,
#   'date_added': '2017-06-01T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 1356449188.9763,
#   'total_supply': 1500000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x0d8775f648430679a709e98d2b0cb6250d2887ef'},
#   'cmc_rank': 30,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': 252604141.92154202},
#  {'id': 3330,
#   'name': 'Paxos Standard',
#   'symbol': 'PAX',
#   'slug': 'paxos-standard',
#   'num_market_pairs': 96,
#   'date_added': '2018-09-27T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 240112317.416244,
#   'total_supply': 240112398.55,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x8e870d67f660d95d5be530380d0ec0bd388289e1'},
#   'cmc_rank': 31,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': 240612098.02758193},
#  {'id': 1437,
#   'name': 'Zcash',
#   'symbol': 'ZEC',
#   'slug': 'zcash',
#   'num_market_pairs': 223,
#   'date_added': '2016-10-29T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 7993931.25,
#   'total_supply': 7993931.25,
#   'platform': None,
#   'cmc_rank': 32,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': 219157387.2035653},
#  {'id': 3662,
#   'name': 'HedgeTrade',
#   'symbol': 'HEDG',
#   'slug': 'hedgetrade',
#   'num_market_pairs': 8,
#   'date_added': '2019-01-03T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 288114855.057208,
#   'total_supply': 1000000000.05,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xF1290473E210b2108A85237fbCd7b6eb42Cc654F'},
#   'cmc_rank': 33,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': 210377287.28839836},
#  {'id': 1168,
#   'name': 'Decred',
#   'symbol': 'DCR',
#   'slug': 'decred',
#   'num_market_pairs': 47,
#   'date_added': '2016-02-10T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000,
#   'circulating_supply': 10766858.9251755,
#   'total_supply': 10766858.9251755,
#   'platform': None,
#   'cmc_rank': 34,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': 209474953.25556454},
#  {'id': 3296,
#   'name': 'MINDOL',
#   'symbol': 'MIN',
#   'slug': 'mindol',
#   'num_market_pairs': 13,
#   'date_added': '2019-03-29T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 141690716,
#   'total_supply': 240000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x5d64d850c8368008afb39224e92ad0dceff3cf38'},
#   'cmc_rank': 35,
#   'last_updated': '2019-12-04T19:20:10.000Z',
#   'quote': 207768470.69086722},
#  {'id': 2586,
#   'name': 'Synthetix Network Token',
#   'symbol': 'SNX',
#   'slug': 'synthetix-network-token',
#   'num_market_pairs': 7,
#   'date_added': '2018-03-14T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 148341865.825791,
#   'total_supply': 154807692.307692,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xc011a72400e58ecd99ee497cf89e3775d4bd732f'},
#   'cmc_rank': 36,
#   'last_updated': '2019-12-04T19:20:08.000Z',
#   'quote': 194430244.37551826},
#  {'id': 1684,
#   'name': 'Qtum',
#   'symbol': 'QTUM',
#   'slug': 'qtum',
#   'num_market_pairs': 178,
#   'date_added': '2017-05-24T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 107822406,
#   'circulating_supply': 96211668.0484598,
#   'total_supply': 101961688,
#   'platform': None,
#   'cmc_rank': 37,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': 168422615.4704636},
#  {'id': 2563,
#   'name': 'TrueUSD',
#   'symbol': 'TUSD',
#   'slug': 'trueusd',
#   'num_market_pairs': 147,
#   'date_added': '2018-03-06T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 157940044.67,
#   'total_supply': 157940044.67,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x0000000000085d4780B73119b644AE5ecd22b376'},
#   'cmc_rank': 38,
#   'last_updated': '2019-12-04T19:20:09.000Z',
#   'quote': 157584077.61465347},
#  {'id': 2585,
#   'name': 'Centrality',
#   'symbol': 'CENNZ',
#   'slug': 'centrality',
#   'num_market_pairs': 2,
#   'date_added': '2018-03-13T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 1069176371.64951,
#   'total_supply': 1200000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x1122b6a0e00dce0563082b6e2953f3a943855c1f'},
#   'cmc_rank': 39,
#   'last_updated': '2019-12-04T19:20:08.000Z',
#   'quote': 145914817.910801},
#  {'id': 1896,
#   'name': '0x',
#   'symbol': 'ZRX',
#   'slug': '0x',
#   'num_market_pairs': 175,
#   'date_added': '2017-08-16T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 602160071.148669,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xe41d2489571d322189246dafa5ebde1f4699f498'},
#   'cmc_rank': 40,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': 144700067.01430705},
#  {'id': 2577,
#   'name': 'Ravencoin',
#   'symbol': 'RVN',
#   'slug': 'ravencoin',
#   'num_market_pairs': 45,
#   'date_added': '2018-03-10T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000000,
#   'circulating_supply': 4996865000,
#   'total_supply': 4996865000,
#   'platform': None,
#   'cmc_rank': 41,
#   'last_updated': '2019-12-04T19:20:08.000Z',
#   'quote': 139748017.2492181},
#  {'id': 4030,
#   'name': 'Algorand',
#   'symbol': 'ALGO',
#   'slug': 'algorand',
#   'num_market_pairs': 60,
#   'date_added': '2019-06-20T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 454946250.472551,
#   'total_supply': 2986218093.47255,
#   'platform': None,
#   'cmc_rank': 42,
#   'last_updated': '2019-12-04T19:20:13.000Z',
#   'quote': 126376491.16821788},
#  {'id': 2682,
#   'name': 'Holo',
#   'symbol': 'HOT',
#   'slug': 'holo',
#   'num_market_pairs': 62,
#   'date_added': '2018-04-29T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 161496951785.847,
#   'total_supply': 177619433541.141,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x6c6ee5e31d828de241282b9606c8e98ea48526e2'},
#   'cmc_rank': 43,
#   'last_updated': '2019-12-04T19:20:09.000Z',
#   'quote': 125894597.21906136},
#  {'id': 2830,
#   'name': 'Seele',
#   'symbol': 'SEELE',
#   'slug': 'seele',
#   'num_market_pairs': 14,
#   'date_added': '2018-05-31T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 699562206.289478,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xb1eef147028e9f480dbc5ccaa3277d417d1b85f0'},
#   'cmc_rank': 44,
#   'last_updated': '2019-12-04T19:20:09.000Z',
#   'quote': 113795507.13965435},
#  {'id': 1104,
#   'name': 'Augur',
#   'symbol': 'REP',
#   'slug': 'augur',
#   'num_market_pairs': 67,
#   'date_added': '2015-10-27T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 11000000,
#   'total_supply': 11000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x1985365e9f78359a9b6ad760e32412f4a445e862'},
#   'cmc_rank': 45,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': 112107443.1499},
#  {'id': 1567,
#   'name': 'Nano',
#   'symbol': 'NANO',
#   'slug': 'nano',
#   'num_market_pairs': 50,
#   'date_added': '2017-03-06T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 133248297.197,
#   'circulating_supply': 133248297.197,
#   'total_supply': 133248297.197,
#   'platform': None,
#   'cmc_rank': 46,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': 110411947.48949243},
#  {'id': 2083,
#   'name': 'Bitcoin Gold',
#   'symbol': 'BTG',
#   'slug': 'bitcoin-gold',
#   'num_market_pairs': 84,
#   'date_added': '2017-10-23T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000,
#   'circulating_supply': 17513923.589,
#   'total_supply': 17513923.589,
#   'platform': None,
#   'cmc_rank': 47,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': 105652741.99958691},
#  {'id': 1808,
#   'name': 'OmiseGO',
#   'symbol': 'OMG',
#   'slug': 'omisego',
#   'num_market_pairs': 203,
#   'date_added': '2017-07-14T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 140245398.245133,
#   'total_supply': 140245398.245133,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xd26114cd6EE289AccF82350c8d8487fedB8A0C07'},
#   'cmc_rank': 48,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': 104585229.6136622},
#  {'id': 3704,
#   'name': 'V Systems',
#   'symbol': 'VSYS',
#   'slug': 'v-systems',
#   'num_market_pairs': 33,
#   'date_added': '2019-03-05T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 1867045420,
#   'total_supply': 3781903884,
#   'platform': None,
#   'cmc_rank': 49,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': 98063005.2053734},
#  {'id': 3437,
#   'name': 'ABBC Coin',
#   'symbol': 'ABBC',
#   'slug': 'abbc-coin',
#   'num_market_pairs': 39,
#   'date_added': '2018-10-12T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 556626634.357622,
#   'total_supply': 1004488460.0178,
#   'platform': None,
#   'cmc_rank': 50,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': 95685150.8181542},
#  {'id': 4195,
#   'name': 'FTX Token',
#   'symbol': 'FTT',
#   'slug': 'ftx-token',
#   'num_market_pairs': 13,
#   'date_added': '2019-07-31T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 52288488.9327723,
#   'total_supply': 348160825,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9'},
#   'cmc_rank': 51,
#   'last_updated': '2019-12-04T19:20:13.000Z',
#   'quote': 93450876.00600272},
#  {'id': 3351,
#   'name': 'ZB',
#   'symbol': 'ZB',
#   'slug': 'zb',
#   'num_market_pairs': 10,
#   'date_added': '2018-09-27T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 463288810,
#   'total_supply': 2100000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xbd0793332e9fb844a52a205a233ef27a5b34b927'},
#   'cmc_rank': 52,
#   'last_updated': '2019-12-04T19:20:10.000Z',
#   'quote': 89909455.19349286},
#  {'id': 109,
#   'name': 'DigiByte',
#   'symbol': 'DGB',
#   'slug': 'digibyte',
#   'num_market_pairs': 78,
#   'date_added': '2014-02-06T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000000,
#   'circulating_supply': 12563015176.4017,
#   'total_supply': 12563015176.4017,
#   'platform': None,
#   'cmc_rank': 53,
#   'last_updated': '2019-12-04T19:20:02.000Z',
#   'quote': 84769741.2748151},
#  {'id': 1214,
#   'name': 'Lisk',
#   'symbol': 'LSK',
#   'slug': 'lisk',
#   'num_market_pairs': 61,
#   'date_added': '2016-04-06T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 121841760.912821,
#   'total_supply': 136862662,
#   'platform': None,
#   'cmc_rank': 54,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': 82469043.68849227},
#  {'id': 1866,
#   'name': 'Bytom',
#   'symbol': 'BTM',
#   'slug': 'bytom',
#   'num_market_pairs': 50,
#   'date_added': '2017-08-08T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 1002499275,
#   'total_supply': 1407000000,
#   'platform': None,
#   'cmc_rank': 55,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': 80587497.82820852},
#  {'id': 3890,
#   'name': 'Matic Network',
#   'symbol': 'MATIC',
#   'slug': 'matic-network',
#   'num_market_pairs': 31,
#   'date_added': '2019-04-28T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 2539297092,
#   'total_supply': 10000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0'},
#   'cmc_rank': 56,
#   'last_updated': '2019-12-04T19:20:12.000Z',
#   'quote': 80580276.79832998},
#  {'id': 1521,
#   'name': 'Komodo',
#   'symbol': 'KMD',
#   'slug': 'komodo',
#   'num_market_pairs': 23,
#   'date_added': '2017-02-05T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 200000000,
#   'circulating_supply': 117292457.72457,
#   'total_supply': 117292457.72457,
#   'platform': None,
#   'cmc_rank': 57,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': 80532463.84728885},
#  {'id': 2087,
#   'name': 'KuCoin Shares',
#   'symbol': 'KCS',
#   'slug': 'kucoin-shares',
#   'num_market_pairs': 15,
#   'date_added': '2017-10-24T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 82363551,
#   'total_supply': 172363551,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x039b5649a59967e3e936d7471f9c3700100ee1ab'},
#   'cmc_rank': 58,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': 79859900.94374856},
#  {'id': 2453,
#   'name': 'EDUCare',
#   'symbol': 'EKT',
#   'slug': 'educare',
#   'num_market_pairs': 6,
#   'date_added': '2018-01-23T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 1000000000,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x4ecdb6385f3db3847f9c4a9bf3f9917bb27a5452'},
#   'cmc_rank': 59,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': 77799965.9233},
#  {'id': 4172,
#   'name': 'LUNA',
#   'symbol': 'LUNA',
#   'slug': 'luna',
#   'num_market_pairs': 10,
#   'date_added': '2019-07-26T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 287765804.430561,
#   'total_supply': 995859074.224591,
#   'platform': None,
#   'cmc_rank': 60,
#   'last_updated': '2019-12-04T19:20:13.000Z',
#   'quote': 72616735.05637142},
#  {'id': 4279,
#   'name': 'Swipe',
#   'symbol': 'SXP',
#   'slug': 'swipe',
#   'num_market_pairs': 9,
#   'date_added': '2019-08-26T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 61135911.166,
#   'total_supply': 300000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x8ce9137d39326ad0cd6491fb5cc0cba0e089b6a9'},
#   'cmc_rank': 61,
#   'last_updated': '2019-12-04T19:20:13.000Z',
#   'quote': 70745363.01058774},
#  {'id': 2405,
#   'name': 'IOST',
#   'symbol': 'IOST',
#   'slug': 'iostoken',
#   'num_market_pairs': 84,
#   'date_added': '2018-01-16T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 12013965608.8475,
#   'total_supply': 21000000000,
#   'platform': None,
#   'cmc_rank': 62,
#   'last_updated': '2019-12-04T19:20:08.000Z',
#   'quote': 69384217.42874722},
#  {'id': 2222,
#   'name': 'Bitcoin Diamond',
#   'symbol': 'BCD',
#   'slug': 'bitcoin-diamond',
#   'num_market_pairs': 25,
#   'date_added': '2017-11-24T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 210000000,
#   'circulating_supply': 186492897.953,
#   'total_supply': 189492897.953,
#   'platform': None,
#   'cmc_rank': 63,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': 68810856.7871182},
#  {'id': 2099,
#   'name': 'ICON',
#   'symbol': 'ICX',
#   'slug': 'icon',
#   'num_market_pairs': 63,
#   'date_added': '2017-10-27T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 507821713.297343,
#   'total_supply': 800460000,
#   'platform': None,
#   'cmc_rank': 64,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': 67369062.39426717},
#  {'id': 3718,
#   'name': 'BitTorrent',
#   'symbol': 'BTT',
#   'slug': 'bittorrent',
#   'num_market_pairs': 129,
#   'date_added': '2019-01-31T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 212116500000,
#   'total_supply': 990000000000,
#   'platform': {'id': 1958,
#    'name': 'TRON',
#    'symbol': 'TRX',
#    'slug': 'tron',
#    'token_address': '1002000'},
#   'cmc_rank': 65,
#   'last_updated': '2019-12-04T19:20:12.000Z',
#   'quote': 65837253.69582482},
#  {'id': 2416,
#   'name': 'THETA',
#   'symbol': 'THETA',
#   'slug': 'theta',
#   'num_market_pairs': 30,
#   'date_added': '2018-01-17T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 870502690,
#   'total_supply': 1000000000,
#   'platform': None,
#   'cmc_rank': 66,
#   'last_updated': '2019-12-04T19:20:08.000Z',
#   'quote': 65140588.87737128},
#  {'id': 1042,
#   'name': 'Siacoin',
#   'symbol': 'SC',
#   'slug': 'siacoin',
#   'num_market_pairs': 38,
#   'date_added': '2015-08-26T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 41817047634,
#   'total_supply': 41817047634,
#   'platform': None,
#   'cmc_rank': 67,
#   'last_updated': '2019-12-04T19:20:03.000Z',
#   'quote': 64375669.96109703},
#  {'id': 1776,
#   'name': 'MCO',
#   'symbol': 'MCO',
#   'slug': 'crypto-com',
#   'num_market_pairs': 57,
#   'date_added': '2017-07-03T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 15793831.0949625,
#   'total_supply': 31587682.3632061,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xb63b606ac810a52cca15e44bb630fd42d8d1d83d'},
#   'cmc_rank': 68,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': 63977987.96654629},
#  {'id': 693,
#   'name': 'Verge',
#   'symbol': 'XVG',
#   'slug': 'verge',
#   'num_market_pairs': 59,
#   'date_added': '2014-10-25T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 16555000000,
#   'circulating_supply': 16087657429.1206,
#   'total_supply': 16087657429.1206,
#   'platform': None,
#   'cmc_rank': 69,
#   'last_updated': '2019-12-04T19:20:03.000Z',
#   'quote': 63963898.024848305},
#  {'id': 2441,
#   'name': 'Molecular Future',
#   'symbol': 'MOF',
#   'slug': 'molecular-future',
#   'num_market_pairs': 11,
#   'date_added': '2018-01-20T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 43842875.0687909,
#   'total_supply': 100000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x653430560be843c4a3d143d0110e896c2ab8ac0d'},
#   'cmc_rank': 70,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': 63186690.61503065},
#  {'id': 3155,
#   'name': 'Quant',
#   'symbol': 'QNT',
#   'slug': 'quant',
#   'num_market_pairs': 18,
#   'date_added': '2018-08-10T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 12072738,
#   'total_supply': 14612493.0808262,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x4a220e6096b25eadb88358cb44068a3248254675'},
#   'cmc_rank': 71,
#   'last_updated': '2019-12-04T19:20:10.000Z',
#   'quote': 61421686.101594426},
#  {'id': 2130,
#   'name': 'Enjin Coin',
#   'symbol': 'ENJ',
#   'slug': 'enjin-coin',
#   'num_market_pairs': 52,
#   'date_added': '2017-11-01T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 784764641.564264,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c'},
#   'cmc_rank': 72,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': 60545377.067717634},
#  {'id': 2308,
#   'name': 'Single Collateral DAI ',
#   'symbol': 'SAI',
#   'slug': 'single-collateral-dai',
#   'num_market_pairs': 45,
#   'date_added': '2017-12-24T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 59941936.0118301,
#   'total_supply': 59941936.0118301,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x89d24a6b4ccb1b6faa2625fe562bdd9a23260359'},
#   'cmc_rank': 73,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': 59994147.487511195},
#  {'id': 213,
#   'name': 'MonaCoin',
#   'symbol': 'MONA',
#   'slug': 'monacoin',
#   'num_market_pairs': 14,
#   'date_added': '2014-03-20T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 65729674.8711679,
#   'total_supply': 65729674.8711679,
#   'platform': None,
#   'cmc_rank': 74,
#   'last_updated': '2019-12-04T19:20:02.000Z',
#   'quote': 59248082.12652192},
#  {'id': 1274,
#   'name': 'Waves',
#   'symbol': 'WAVES',
#   'slug': 'waves',
#   'num_market_pairs': 142,
#   'date_added': '2016-06-02T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 100508260,
#   'total_supply': 100508260,
#   'platform': None,
#   'cmc_rank': 75,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': 58583590.46439073},
#  {'id': 372,
#   'name': 'Bytecoin',
#   'symbol': 'BCN',
#   'slug': 'bytecoin-bcn',
#   'num_market_pairs': 11,
#   'date_added': '2014-06-17T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 184470000000,
#   'circulating_supply': 184066828814.059,
#   'total_supply': 184066828814.059,
#   'platform': None,
#   'cmc_rank': 76,
#   'last_updated': '2019-12-04T19:20:03.000Z',
#   'quote': 58563526.660804376},
#  {'id': 3139,
#   'name': 'DxChain Token',
#   'symbol': 'DX',
#   'slug': 'dxchain-token',
#   'num_market_pairs': 8,
#   'date_added': '2018-08-10T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 49999999999.6862,
#   'total_supply': 100000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x973e52691176d36453868D9d86572788d27041A9'},
#   'cmc_rank': 77,
#   'last_updated': '2019-12-04T19:20:10.000Z',
#   'quote': 57260510.47264063},
#  {'id': 463,
#   'name': 'BitShares',
#   'symbol': 'BTS',
#   'slug': 'bitshares',
#   'num_market_pairs': 85,
#   'date_added': '2014-07-21T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 3600570502,
#   'circulating_supply': 2748920000,
#   'total_supply': 2748920000,
#   'platform': None,
#   'cmc_rank': 78,
#   'last_updated': '2019-12-04T19:20:03.000Z',
#   'quote': 56351982.061475866},
#  {'id': 2469,
#   'name': 'Zilliqa',
#   'symbol': 'ZIL',
#   'slug': 'zilliqa',
#   'num_market_pairs': 104,
#   'date_added': '2018-01-25T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 9729027774.34355,
#   'total_supply': 13020494927.3436,
#   'platform': None,
#   'cmc_rank': 79,
#   'last_updated': '2019-12-04T19:20:08.000Z',
#   'quote': 55309113.48321228},
#  {'id': 291,
#   'name': 'MaidSafeCoin',
#   'symbol': 'MAID',
#   'slug': 'maidsafecoin',
#   'num_market_pairs': 6,
#   'date_added': '2014-04-28T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 452552412,
#   'total_supply': 452552412,
#   'platform': {'id': 83,
#    'name': 'Omni',
#    'symbol': 'OMNI',
#    'slug': 'omni',
#    'token_address': '3'},
#   'cmc_rank': 80,
#   'last_updated': '2019-12-04T19:20:02.000Z',
#   'quote': 55121256.54721155},
#  {'id': 1903,
#   'name': 'HyperCash',
#   'symbol': 'HC',
#   'slug': 'hypercash',
#   'num_market_pairs': 32,
#   'date_added': '2017-08-20T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 84000000,
#   'circulating_supply': 44445722.337052,
#   'total_supply': 44445722.337052,
#   'platform': None,
#   'cmc_rank': 81,
#   'last_updated': '2019-12-04T19:20:06.000Z',
#   'quote': 54754530.38361796},
#  {'id': 2694,
#   'name': 'Nexo',
#   'symbol': 'NEXO',
#   'slug': 'nexo',
#   'num_market_pairs': 21,
#   'date_added': '2018-05-01T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 560000011,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xb62132e35a6c13ee1ee0f84dc5d40bad8d815206'},
#   'cmc_rank': 82,
#   'last_updated': '2019-12-04T19:20:09.000Z',
#   'quote': 53784804.55520721},
#  {'id': 1320,
#   'name': 'Ardor',
#   'symbol': 'ARDR',
#   'slug': 'ardor',
#   'num_market_pairs': 26,
#   'date_added': '2016-07-23T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 998999495,
#   'circulating_supply': 998999495,
#   'total_supply': 998999495,
#   'platform': None,
#   'cmc_rank': 83,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': 48544103.58453128},
#  {'id': 1700,
#   'name': 'Aeternity',
#   'symbol': 'AE',
#   'slug': 'aeternity',
#   'num_market_pairs': 51,
#   'date_added': '2017-06-01T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': None,
#   'circulating_supply': 293276971.5,
#   'total_supply': 339097915.49932,
#   'platform': None,
#   'cmc_rank': 84,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': 46957564.27841354},
#  {'id': 1637,
#   'name': 'iExec RLC',
#   'symbol': 'RLC',
#   'slug': 'rlc',
#   'num_market_pairs': 17,
#   'date_added': '2017-04-20T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 80070793.2387674,
#   'total_supply': 86999784.9868455,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x607f4c5bb672230e8672085532f7e901544a7375'},
#   'cmc_rank': 85,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': 44282536.00398039},
#  {'id': 1230,
#   'name': 'Steem',
#   'symbol': 'STEEM',
#   'slug': 'steem',
#   'num_market_pairs': 33,
#   'date_added': '2016-04-18T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 353003191.076,
#   'total_supply': 369977285.076,
#   'platform': None,
#   'cmc_rank': 86,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': 43493670.57107441},
#  {'id': 1698,
#   'name': 'Horizen',
#   'symbol': 'ZEN',
#   'slug': 'horizen',
#   'num_market_pairs': 34,
#   'date_added': '2017-06-01T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000,
#   'circulating_supply': 7906087.5,
#   'total_supply': 7906087.5,
#   'platform': None,
#   'cmc_rank': 87,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': 41143310.78484108},
#  {'id': 4066,
#   'name': 'Chiliz',
#   'symbol': 'CHZ',
#   'slug': 'chiliz',
#   'num_market_pairs': 10,
#   'date_added': '2019-07-01T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 3763769182,
#   'total_supply': 8888888888,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x3506424f91fd33084466f402d5d97f05f8e3b4af'},
#   'cmc_rank': 88,
#   'last_updated': '2019-12-04T19:20:12.000Z',
#   'quote': 40406321.86578076},
#  {'id': 3724,
#   'name': 'SOLVE',
#   'symbol': 'SOLVE',
#   'slug': 'solve',
#   'num_market_pairs': 9,
#   'date_added': '2019-02-04T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 1000000000,
#   'circulating_supply': 327424138.235688,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x446c9033e7516d820cc9a2ce2d0b7328b579406f'},
#   'cmc_rank': 89,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': 39607311.307934545},
#  {'id': 3773,
#   'name': 'Fetch.ai',
#   'symbol': 'FET',
#   'slug': 'fetch',
#   'num_market_pairs': 28,
#   'date_added': '2019-03-02T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 1152997575,
#   'circulating_supply': 654717118.965709,
#   'total_supply': 1152997575,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x1d287cc25dad7ccaf76a26bc660c5f7c8e2a05bd'},
#   'cmc_rank': 90,
#   'last_updated': '2019-12-04T19:20:12.000Z',
#   'quote': 38788459.09170733},
#  {'id': 2137,
#   'name': 'Electroneum',
#   'symbol': 'ETN',
#   'slug': 'electroneum',
#   'num_market_pairs': 20,
#   'date_added': '2017-11-02T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 21000000000,
#   'circulating_supply': 9909722400.95,
#   'total_supply': 9909722400.95,
#   'platform': None,
#   'cmc_rank': 91,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': 38059512.30217672},
#  {'id': 1759,
#   'name': 'Status',
#   'symbol': 'SNT',
#   'slug': 'status',
#   'num_market_pairs': 86,
#   'date_added': '2017-06-28T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 3470483788,
#   'total_supply': 6804870174,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x744d70fdbe2ba4cf95131626614a1763df805b9e'},
#   'cmc_rank': 92,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': 37978952.22605994},
#  {'id': 2603,
#   'name': 'Pundi X',
#   'symbol': 'NPXS',
#   'slug': 'pundi-x',
#   'num_market_pairs': 69,
#   'date_added': '2018-03-22T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 234562817276.377,
#   'total_supply': 259810708832.63,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa15c7ebe1f07caf6bff097d8a589fb8ac49ae5b3'},
#   'cmc_rank': 93,
#   'last_updated': '2019-12-04T19:20:08.000Z',
#   'quote': 37221848.86589999},
#  {'id': 2044,
#   'name': 'Enigma',
#   'symbol': 'ENG',
#   'slug': 'enigma',
#   'num_market_pairs': 27,
#   'date_added': '2017-10-13T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 74836171.09,
#   'total_supply': 150000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xf0ee6b27b759c9893ce4f094b49ad28fd15a23e4'},
#   'cmc_rank': 94,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': 36791148.38425191},
#  {'id': 1455,
#   'name': 'Golem',
#   'symbol': 'GNT',
#   'slug': 'golem-network-tokens',
#   'num_market_pairs': 98,
#   'date_added': '2016-11-18T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 980050000,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa74476443119A942dE498590Fe1f2454d7D4aC0d'},
#   'cmc_rank': 95,
#   'last_updated': '2019-12-04T19:20:05.000Z',
#   'quote': 36440070.60811627},
#  {'id': 3617,
#   'name': 'ILCoin',
#   'symbol': 'ILC',
#   'slug': 'ilcoin',
#   'num_market_pairs': 26,
#   'date_added': '2018-11-26T00:00:00.000Z',
#   'tags': ['mineable'],
#   'max_supply': 2500000000,
#   'circulating_supply': 345442487.370894,
#   'total_supply': 1299138907.43547,
#   'platform': None,
#   'cmc_rank': 96,
#   'last_updated': '2019-12-04T19:20:11.000Z',
#   'quote': 36214606.42370883},
#  {'id': 2447,
#   'name': 'Crypterium',
#   'symbol': 'CRPT',
#   'slug': 'crpt',
#   'num_market_pairs': 9,
#   'date_added': '2018-01-22T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 84759818.6100001,
#   'total_supply': 99757369.7528572,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x80a7e048f37a50500351c204cb407766fa3bae7f'},
#   'cmc_rank': 97,
#   'last_updated': '2019-12-04T19:20:07.000Z',
#   'quote': 36075210.59717593},
#  {'id': 2772,
#   'name': 'Digitex Futures',
#   'symbol': 'DGTX',
#   'slug': 'digitex-futures',
#   'num_market_pairs': 7,
#   'date_added': '2018-05-23T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 786260027.490069,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x1c83501478f1320977047008496dacbd60bb15ef'},
#   'cmc_rank': 98,
#   'last_updated': '2019-12-04T19:20:09.000Z',
#   'quote': 35967337.09404051},
#  {'id': 1229,
#   'name': 'DigixDAO',
#   'symbol': 'DGD',
#   'slug': 'digixdao',
#   'num_market_pairs': 27,
#   'date_added': '2016-04-18T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 2000000,
#   'total_supply': 2000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xe0b7927c4af23765cb51314a0e0521a9645f0e2a'},
#   'cmc_rank': 99,
#   'last_updated': '2019-12-04T19:20:04.000Z',
#   'quote': 35909146.5926},
#  {'id': 2989,
#   'name': 'STASIS EURO',
#   'symbol': 'EURS',
#   'slug': 'stasis-euro',
#   'num_market_pairs': 29,
#   'date_added': '2018-07-30T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 31979207,
#   'total_supply': 31979207,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xdb25f211ab05b1c97d595516f45794528a807ad8'},
#   'cmc_rank': 100,
#   'last_updated': '2019-12-04T19:20:10.000Z',
#   'quote': 35235885.35251457}]
