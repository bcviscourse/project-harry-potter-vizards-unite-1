# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '8156fd5c-1e27-4c73-8393-fef3b616fe8d',
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
# Out:
# {'status': {'timestamp': '2019-12-04T16:37:06.757Z', 'error_code': 0, 'error_message': None, 'elapsed': 15, 'credit_count': 1, 'notice': None}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 7719, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18083012, 'total_supply': 18083012, 'platform': None, 'cmc_rank': 1, 'last_updated': '2019-12-04T16:36:39.000Z', 'quote': {'USD': {'price': 7473.33358131, 'volume_24h': 19359325961.0166, 'percent_change_1h': -0.209582, 'percent_change_24h': 1.36571, 'percent_change_7d': 1.31537, 'market_cap': 135140380830.83171, 'last_updated': '2019-12-04T16:36:39.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 5336, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': None, 'circulating_supply': 108796454.749, 'total_supply': 108796454.749, 'platform': None, 'cmc_rank': 2, 'last_updated': '2019-12-04T16:36:23.000Z', 'quote': {'USD': {'price': 149.574425867, 'volume_24h': 7441687171.12115, 'percent_change_1h': -0.102632, 'percent_change_24h': 0.243996, 'percent_change_7d': -0.746315, 'market_cap': 16273167255.44672, 'last_updated': '2019-12-04T16:36:23.000Z'}}}, {'id': 52, 'name': 'XRP', 'symbol': 'XRP', 'slug': 'xrp', 'num_market_pairs': 508, 'date_added': '2013-08-04T00:00:00.000Z', 'tags': [], 'max_supply': 100000000000, 'circulating_supply': 43285660917, 'total_supply': 99991237614, 'platform': None, 'cmc_rank': 3, 'last_updated': '2019-12-04T16:36:06.000Z', 'quote': {'USD': {'price': 0.220124015908, 'volume_24h': 1339776344.04373, 'percent_change_1h': -0.144137, 'percent_change_24h': -0.631323, 'percent_change_7d': -1.33052, 'market_cap': 9528213512.282001, 'last_updated': '2019-12-04T16:36:06.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 3927, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': [], 'max_supply': None, 'circulating_supply': 4108044456.1, 'total_supply': 4207771504.46, 'platform': {'id': 83, 'name': 'Omni', 'symbol': 'OMNI', 'slug': 'omni', 'token_address': '31'}, 'cmc_rank': 4, 'last_updated': '2019-12-04T16:36:21.000Z', 'quote': {'USD': {'price': 1.00117825419, 'volume_24h': 22037500478.6887, 'percent_change_1h': -0.344664, 'percent_change_24h': -0.441049, 'percent_change_7d': -0.202884, 'market_cap': 4112884776.693106, 'last_updated': '2019-12-04T16:36:21.000Z'}}}, {'id': 1831, 'name': 'Bitcoin Cash', 'symbol': 'BCH', 'slug': 'bitcoin-cash', 'num_market_pairs': 440, 'date_added': '2017-07-23T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18148537.5, 'total_supply': 18148537.5, 'platform': None, 'cmc_rank': 5, 'last_updated': '2019-12-04T16:36:08.000Z', 'quote': {'USD': {'price': 214.724863297, 'volume_24h': 1405778696.8401, 'percent_change_1h': -0.361312, 'percent_change_24h': -0.158719, 'percent_change_7d': -1.00116, 'market_cap': 3896942233.727978, 'last_updated': '2019-12-04T16:36:08.000Z'}}}, {'id': 2, 'name': 'Litecoin', 'symbol': 'LTC', 'slug': 'litecoin', 'num_market_pairs': 557, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 84000000, 'circulating_supply': 63769119.2668217, 'total_supply': 63769119.2668217, 'platform': None, 'cmc_rank': 6, 'last_updated': '2019-12-04T16:36:06.000Z', 'quote': {'USD': {'price': 46.0341032287, 'volume_24h': 2864643850.02982, 'percent_change_1h': -0.227453, 'percent_change_24h': -0.583959, 'percent_change_7d': -2.96373, 'market_cap': 2935554219.132152, 'last_updated': '2019-12-04T16:36:06.000Z'}}}, {'id': 1765, 'name': 'EOS', 'symbol': 'EOS', 'slug': 'eos', 'num_market_pairs': 394, 'date_added': '2017-07-01T00:00:00.000Z', 'tags': [], 'max_supply': None, 'circulating_supply': 942932350.6709, 'total_supply': 1039632362.163, 'platform': None, 'cmc_rank': 7, 'last_updated': '2019-12-04T16:36:07.000Z', 'quote': {'USD': {'price': 2.69730896384, 'volu ...

# %%
data
# Out:
# {'status': {'timestamp': '2019-12-04T16:37:06.757Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 15,
#   'credit_count': 1,
#   'notice': None},
#  'data': [{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'num_market_pairs': 7719,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 21000000,
#    'circulating_supply': 18083012,
#    'total_supply': 18083012,
#    'platform': None,
#    'cmc_rank': 1,
#    'last_updated': '2019-12-04T16:36:39.000Z',
#    'quote': {'USD': {'price': 7473.33358131,
#      'volume_24h': 19359325961.0166,
#      'percent_change_1h': -0.209582,
#      'percent_change_24h': 1.36571,
#      'percent_change_7d': 1.31537,
#      'market_cap': 135140380830.83171,
#      'last_updated': '2019-12-04T16:36:39.000Z'}}},
#   {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'num_market_pairs': 5336,
#    'date_added': '2015-08-07T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': None,
#    'circulating_supply': 108796454.749,
#    'total_supply': 108796454.749,
#    'platform': None,
#    'cmc_rank': 2,
#    'last_updated': '2019-12-04T16:36:23.000Z',
#    'quote': {'USD': {'price': 149.574425867,
#      'volume_24h': 7441687171.12115,
#      'percent_change_1h': -0.102632,
#      'percent_change_24h': 0.243996,
#      'percent_change_7d': -0.746315,
#      'market_cap': 16273167255.44672,
#      'last_updated': '2019-12-04T16:36:23.000Z'}}},
#   {'id': 52,
#    'name': 'XRP',
#    'symbol': 'XRP',
#    'slug': 'xrp',
#    'num_market_pairs': 508,
#    'date_added': '2013-08-04T00:00:00.000Z',
#    'tags': [],
#    'max_supply': 100000000000,
#    'circulating_supply': 43285660917,
#    'total_supply': 99991237614,
#    'platform': None,
#    'cmc_rank': 3,
#    'last_updated': '2019-12-04T16:36:06.000Z',
#    'quote': {'USD': {'price': 0.220124015908,
#      'volume_24h': 1339776344.04373,
#      'percent_change_1h': -0.144137,
#      'percent_change_24h': -0.631323,
#      'percent_change_7d': -1.33052,
#      'market_cap': 9528213512.282001,
#      'last_updated': '2019-12-04T16:36:06.000Z'}}},
#   {'id': 825,
#    'name': 'Tether',
#    'symbol': 'USDT',
#    'slug': 'tether',
#    'num_market_pairs': 3927,
#    'date_added': '2015-02-25T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 4108044456.1,
#    'total_supply': 4207771504.46,
#    'platform': {'id': 83,
#     'name': 'Omni',
#     'symbol': 'OMNI',
#     'slug': 'omni',
#     'token_address': '31'},
#    'cmc_rank': 4,
#    'last_updated': '2019-12-04T16:36:21.000Z',
#    'quote': {'USD': {'price': 1.00117825419,
#      'volume_24h': 22037500478.6887,
#      'percent_change_1h': -0.344664,
#      'percent_change_24h': -0.441049,
#      'percent_change_7d': -0.202884,
#      'market_cap': 4112884776.693106,
#      'last_updated': '2019-12-04T16:36:21.000Z'}}},
#   {'id': 1831,
#    'name': 'Bitcoin Cash',
#    'symbol': 'BCH',
#    'slug': 'bitcoin-cash',
#    'num_market_pairs': 440,
#    'date_added': '2017-07-23T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 21000000,
#    'circulating_supply': 18148537.5,
#    'total_supply': 18148537.5,
#    'platform': None,
#    'cmc_rank': 5,
#    'last_updated': '2019-12-04T16:36:08.000Z',
#    'quote': {'USD': {'price': 214.724863297,
#      'volume_24h': 1405778696.8401,
#      'percent_change_1h': -0.361312,
#      'percent_change_24h': -0.158719,
#      'percent_change_7d': -1.00116,
#      'market_cap': 3896942233.727978,
#      'last_updated': '2019-12-04T16:36:08.000Z'}}},
#   {'id': 2,
#    'name': 'Litecoin',
#    'symbol': 'LTC',
#    'slug': 'litecoin',
#    'num_market_pairs': 557,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 84000000,
#    'circulating_supply': 63769119.2668217,
#    'total_supply': 63769119.2668217,
#    'platform': None,
#    'cmc_rank': 6,
#    'last_updated': '2019-12-04T16:36:06.000Z',
#    'quote': {'USD': {'price': 46.0341032287,
#      'volume_24h': 2864643850.02982,
#      'percent_change_1h': -0.227453,
#      'percent_change_24h': -0.583959,
#      'percent_change_7d': -2.96373,
#      'market_cap': 2935554219.132152,
#      'last_updated': '2019-12-04T16:36:06.000Z'}}},
#   {'id': 1765,
#    'name': 'EOS',
#    'symbol': 'EOS',
#    'slug': 'eos',
#    'num_market_pairs': 394,
#    'date_added': '2017-07-01T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 942932350.6709,
#    'total_supply': 1039632362.163,
#    'platform': None,
#    'cmc_rank': 7,
#    'last_updated': '2019-12-04T16:36:07.000Z',
#    'quote': {'USD': {'price': 2.69730896384,
#      'volume_24h': 1876270203.22049,
#      'percent_change_1h': -0.360077,
#      'percent_change_24h': -1.08028,
#      'percent_change_7d': 1.71055,
#      'market_cap': 2543379881.759341,
#      'last_updated': '2019-12-04T16:36:07.000Z'}}},
#   {'id': 1839,
#    'name': 'Binance Coin',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'num_market_pairs': 283,
#    'date_added': '2017-07-25T00:00:00.000Z',
#    'tags': [],
#    'max_supply': 187536713,
#    'circulating_supply': 155536713,
#    'total_supply': 187536713,
#    'platform': None,
#    'cmc_rank': 8,
#    'last_updated': '2019-12-04T16:36:06.000Z',
#    'quote': {'USD': {'price': 15.5532838427,
#      'volume_24h': 251699690.391457,
#      'percent_change_1h': -0.0761658,
#      'percent_change_24h': 0.870505,
#      'percent_change_7d': -1.15653,
#      'market_cap': 2419106645.249567,
#      'last_updated': '2019-12-04T16:36:06.000Z'}}},
#   {'id': 3602,
#    'name': 'Bitcoin SV',
#    'symbol': 'BSV',
#    'slug': 'bitcoin-sv',
#    'num_market_pairs': 154,
#    'date_added': '2018-11-09T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 21000000,
#    'circulating_supply': 18068415,
#    'total_supply': 18068415,
#    'platform': None,
#    'cmc_rank': 9,
#    'last_updated': '2019-12-04T16:36:13.000Z',
#    'quote': {'USD': {'price': 98.0679969663,
#      'volume_24h': 471758047.554561,
#      'percent_change_1h': -0.479712,
#      'percent_change_24h': 0.0910038,
#      'percent_change_7d': -8.52796,
#      'market_cap': 1771933267.4058495,
#      'last_updated': '2019-12-04T16:36:13.000Z'}}},
#   {'id': 512,
#    'name': 'Stellar',
#    'symbol': 'XLM',
#    'slug': 'stellar',
#    'num_market_pairs': 306,
#    'date_added': '2014-08-05T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 20054779553.7,
#    'total_supply': 50000000000,
#    'platform': None,
#    'cmc_rank': 10,
#    'last_updated': '2019-12-04T16:36:04.000Z',
#    'quote': {'USD': {'price': 0.0563070077891,
#      'volume_24h': 179684588.621182,
#      'percent_change_1h': 0.286669,
#      'percent_change_24h': 0.0932471,
#      'percent_change_7d': -3.75374,
#      'market_cap': 1129224628.5388694,
#      'last_updated': '2019-12-04T16:36:04.000Z'}}},
#   {'id': 1958,
#    'name': 'TRON',
#    'symbol': 'TRX',
#    'slug': 'tron',
#    'num_market_pairs': 300,
#    'date_added': '2017-09-13T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': None,
#    'circulating_supply': 66682072191.4,
#    'total_supply': 99281283754.3,
#    'platform': None,
#    'cmc_rank': 11,
#    'last_updated': '2019-12-04T16:36:06.000Z',
#    'quote': {'USD': {'price': 0.0147198829576,
#      'volume_24h': 950942987.233136,
#      'percent_change_1h': -0.589873,
#      'percent_change_24h': -5.05374,
#      'percent_change_7d': -6.72845,
#      'market_cap': 981552298.0276418,
#      'last_updated': '2019-12-04T16:36:06.000Z'}}},
#   {'id': 2010,
#    'name': 'Cardano',
#    'symbol': 'ADA',
#    'slug': 'cardano',
#    'num_market_pairs': 118,
#    'date_added': '2017-10-01T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 45000000000,
#    'circulating_supply': 25927070538,
#    'total_supply': 31112483745,
#    'platform': None,
#    'cmc_rank': 12,
#    'last_updated': '2019-12-04T16:36:06.000Z',
#    'quote': {'USD': {'price': 0.0377610376113,
#      'volume_24h': 46383235.8220897,
#      'percent_change_1h': -0.351951,
#      'percent_change_24h': -1.76947,
#      'percent_change_7d': -1.97519,
#      'market_cap': 979033085.7362461,
#      'last_updated': '2019-12-04T16:36:06.000Z'}}},
#   {'id': 328,
#    'name': 'Monero',
#    'symbol': 'XMR',
#    'slug': 'monero',
#    'num_market_pairs': 129,
#    'date_added': '2014-05-21T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': None,
#    'circulating_supply': 17338961.959941,
#    'total_supply': 17338961.959941,
#    'platform': None,
#    'cmc_rank': 13,
#    'last_updated': '2019-12-04T16:36:03.000Z',
#    'quote': {'USD': {'price': 54.3624500335,
#      'volume_24h': 155707648.983041,
#      'percent_change_1h': -1.01175,
#      'percent_change_24h': -0.285039,
#      'percent_change_7d': 0.139955,
#      'market_cap': 942588453.1800498,
#      'last_updated': '2019-12-04T16:36:03.000Z'}}},
#   {'id': 3957,
#    'name': 'UNUS SED LEO',
#    'symbol': 'LEO',
#    'slug': 'unus-sed-leo',
#    'num_market_pairs': 26,
#    'date_added': '2019-05-21T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 999498892.9,
#    'total_supply': 999498892.9,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3'},
#    'cmc_rank': 14,
#    'last_updated': '2019-12-04T16:36:14.000Z',
#    'quote': {'USD': {'price': 0.918505215904,
#      'volume_24h': 6517410.02385882,
#      'percent_change_1h': -0.154121,
#      'percent_change_24h': 0.00333065,
#      'percent_change_7d': 1.52836,
#      'market_cap': 918044946.4189235,
#      'last_updated': '2019-12-04T16:36:14.000Z'}}},
#   {'id': 2011,
#    'name': 'Tezos',
#    'symbol': 'XTZ',
#    'slug': 'tezos',
#    'num_market_pairs': 55,
#    'date_added': '2017-10-02T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 660373611.97278,
#    'total_supply': 801312599.488106,
#    'platform': None,
#    'cmc_rank': 15,
#    'last_updated': '2019-12-04T16:36:05.000Z',
#    'quote': {'USD': {'price': 1.28062941154,
#      'volume_24h': 46642060.5294766,
#      'percent_change_1h': -0.316469,
#      'percent_change_24h': -0.697031,
#      'percent_change_7d': 5.29978,
#      'market_cap': 845693870.0972456,
#      'last_updated': '2019-12-04T16:36:05.000Z'}}},
#   {'id': 1975,
#    'name': 'Chainlink',
#    'symbol': 'LINK',
#    'slug': 'chainlink',
#    'num_market_pairs': 120,
#    'date_added': '2017-09-20T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 350000000,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#    'cmc_rank': 16,
#    'last_updated': '2019-12-04T16:36:05.000Z',
#    'quote': {'USD': {'price': 2.09516629523,
#      'volume_24h': 143932498.847649,
#      'percent_change_1h': -0.66601,
#      'percent_change_24h': -3.96879,
#      'percent_change_7d': -6.49829,
#      'market_cap': 733308203.3305,
#      'last_updated': '2019-12-04T16:36:05.000Z'}}},
#   {'id': 3794,
#    'name': 'Cosmos',
#    'symbol': 'ATOM',
#    'slug': 'cosmos',
#    'num_market_pairs': 99,
#    'date_added': '2019-03-14T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 190688439.2,
#    'total_supply': 237928230.821588,
#    'platform': None,
#    'cmc_rank': 17,
#    'last_updated': '2019-12-04T16:36:13.000Z',
#    'quote': {'USD': {'price': 3.68333125225,
#      'volume_24h': 176584933.400599,
#      'percent_change_1h': -0.179724,
#      'percent_change_24h': -1.3346,
#      'percent_change_7d': 3.13403,
#      'market_cap': 702368687.548134,
#      'last_updated': '2019-12-04T16:36:13.000Z'}}},
#   {'id': 2502,
#    'name': 'Huobi Token',
#    'symbol': 'HT',
#    'slug': 'huobi-token',
#    'num_market_pairs': 128,
#    'date_added': '2018-02-03T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 241284046.971921,
#    'total_supply': 500000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6f259637dcd74c767781e37bc6133cd6a68aa161'},
#    'cmc_rank': 18,
#    'last_updated': '2019-12-04T16:36:08.000Z',
#    'quote': {'USD': {'price': 2.89565152914,
#      'volume_24h': 133801336.805033,
#      'percent_change_1h': -0.0194546,
#      'percent_change_24h': -3.02815,
#      'percent_change_7d': 12.0094,
#      'market_cap': 698674519.5713305,
#      'last_updated': '2019-12-04T16:36:08.000Z'}}},
#   {'id': 1376,
#    'name': 'NEO',
#    'symbol': 'NEO',
#    'slug': 'neo',
#    'num_market_pairs': 226,
#    'date_added': '2016-09-08T00:00:00.000Z',
#    'tags': [],
#    'max_supply': 100000000,
#    'circulating_supply': 70538831,
#    'total_supply': 100000000,
#    'platform': None,
#    'cmc_rank': 19,
#    'last_updated': '2019-12-04T16:36:05.000Z',
#    'quote': {'USD': {'price': 8.97399924644,
#      'volume_24h': 328790498.761249,
#      'percent_change_1h': -0.152296,
#      'percent_change_24h': -1.57885,
#      'percent_change_7d': -4.19418,
#      'market_cap': 633015416.2387586,
#      'last_updated': '2019-12-04T16:36:05.000Z'}}},
#   {'id': 1720,
#    'name': 'IOTA',
#    'symbol': 'MIOTA',
#    'slug': 'iota',
#    'num_market_pairs': 48,
#    'date_added': '2017-06-13T00:00:00.000Z',
#    'tags': [],
#    'max_supply': 2779530283,
#    'circulating_supply': 2779530283,
#    'total_supply': 2779530283,
#    'platform': None,
#    'cmc_rank': 20,
#    'last_updated': '2019-12-04T16:36:04.000Z',
#    'quote': {'USD': {'price': 0.205169280972,
#      'volume_24h': 7485930.8823381,
#      'percent_change_1h': -0.279688,
#      'percent_change_24h': 0.255829,
#      'percent_change_7d': -3.24527,
#      'market_cap': 570274229.6030097,
#      'last_updated': '2019-12-04T16:36:04.000Z'}}},
#   {'id': 1518,
#    'name': 'Maker',
#    'symbol': 'MKR',
#    'slug': 'maker',
#    'num_market_pairs': 70,
#    'date_added': '2017-01-29T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 1000000,
#    'total_supply': 1000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2'},
#    'cmc_rank': 21,
#    'last_updated': '2019-12-04T16:36:04.000Z',
#    'quote': {'USD': {'price': 555.50468358,
#      'volume_24h': 4894551.3411178,
#      'percent_change_1h': -1.48514,
#      'percent_change_24h': -0.553752,
#      'percent_change_7d': 1.84686,
#      'market_cap': 555504683.58,
#      'last_updated': '2019-12-04T16:36:04.000Z'}}},
#   {'id': 131,
#    'name': 'Dash',
#    'symbol': 'DASH',
#    'slug': 'dash',
#    'num_market_pairs': 271,
#    'date_added': '2014-02-14T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 18900000,
#    'circulating_supply': 9192916.36121232,
#    'total_supply': 9192916.36121232,
#    'platform': None,
#    'cmc_rank': 22,
#    'last_updated': '2019-12-04T16:36:04.000Z',
#    'quote': {'USD': {'price': 51.571478435,
#      'volume_24h': 239079323.065949,
#      'percent_change_1h': 0.237918,
#      'percent_change_24h': -0.953014,
#      'percent_change_7d': 0.842348,
#      'market_cap': 474092287.8770199,
#      'last_updated': '2019-12-04T16:36:04.000Z'}}},
#   {'id': 3408,
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'slug': 'usd-coin',
#    'num_market_pairs': 182,
#    'date_added': '2018-10-08T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 463611839.585789,
#    'total_supply': 466027388.1,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#    'cmc_rank': 23,
#    'last_updated': '2019-12-04T16:36:13.000Z',
#    'quote': {'USD': {'price': 1.00092108128,
#      'volume_24h': 244715080.425817,
#      'percent_change_1h': -0.349929,
#      'percent_change_24h': -0.372182,
#      'percent_change_7d': -0.480786,
#      'market_cap': 464038863.77241784,
#      'last_updated': '2019-12-04T16:36:13.000Z'}}},
#   {'id': 1321,
#    'name': 'Ethereum Classic',
#    'symbol': 'ETC',
#    'slug': 'ethereum-classic',
#    'num_market_pairs': 220,
#    'date_added': '2016-07-24T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 210000000,
#    'circulating_supply': 115604208,
#    'total_supply': 115604208,
#    'platform': None,
#    'cmc_rank': 24,
#    'last_updated': '2019-12-04T16:36:05.000Z',
#    'quote': {'USD': {'price': 3.84593047365,
#      'volume_24h': 486604217.431846,
#      'percent_change_1h': -0.0252633,
#      'percent_change_24h': -0.946526,
#      'percent_change_7d': -1.80992,
#      'market_cap': 444605746.42937315,
#      'last_updated': '2019-12-04T16:36:05.000Z'}}},
#   {'id': 3077,
#    'name': 'VeChain',
#    'symbol': 'VET',
#    'slug': 'vechain',
#    'num_market_pairs': 85,
#    'date_added': '2017-08-22T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 55454734800,
#    'total_supply': 86712634466,
#    'platform': None,
#    'cmc_rank': 25,
#    'last_updated': '2019-12-04T16:36:11.000Z',
#    'quote': {'USD': {'price': 0.00742532259847,
#      'volume_24h': 134122307.86843,
#      'percent_change_1h': -0.908816,
#      'percent_change_24h': 6.07931,
#      'percent_change_7d': 14.8449,
#      'market_cap': 411769295.5026007,
#      'last_updated': '2019-12-04T16:36:11.000Z'}}},
#   {'id': 2566,
#    'name': 'Ontology',
#    'symbol': 'ONT',
#    'slug': 'ontology',
#    'num_market_pairs': 106,
#    'date_added': '2018-03-08T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 637351170,
#    'total_supply': 1000000000,
#    'platform': None,
#    'cmc_rank': 26,
#    'last_updated': '2019-12-04T16:36:08.000Z',
#    'quote': {'USD': {'price': 0.612828439248,
#      'volume_24h': 75394104.8072532,
#      'percent_change_1h': -0.577211,
#      'percent_change_24h': -1.62512,
#      'percent_change_7d': -3.45837,
#      'market_cap': 390586922.7639867,
#      'last_updated': '2019-12-04T16:36:08.000Z'}}},
#   {'id': 873,
#    'name': 'NEM',
#    'symbol': 'XEM',
#    'slug': 'nem',
#    'num_market_pairs': 96,
#    'date_added': '2015-04-01T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 8999999999,
#    'total_supply': 8999999999,
#    'platform': None,
#    'cmc_rank': 27,
#    'last_updated': '2019-12-04T16:36:03.000Z',
#    'quote': {'USD': {'price': 0.0362520667076,
#      'volume_24h': 15122644.4568145,
#      'percent_change_1h': -3.05586,
#      'percent_change_24h': 2.61453,
#      'percent_change_7d': -0.95741,
#      'market_cap': 326268600.3321479,
#      'last_updated': '2019-12-04T16:36:03.000Z'}}},
#   {'id': 3635,
#    'name': 'Crypto.com Coin',
#    'symbol': 'CRO',
#    'slug': 'crypto-com-coin',
#    'num_market_pairs': 38,
#    'date_added': '2018-12-14T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 12105022831.0502,
#    'total_supply': 100000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#    'cmc_rank': 28,
#    'last_updated': '2019-12-04T16:36:13.000Z',
#    'quote': {'USD': {'price': 0.0264814768376,
#      'volume_24h': 2857620.94474724,
#      'percent_change_1h': -0.134467,
#      'percent_change_24h': 0.681206,
#      'percent_change_7d': -5.51026,
#      'market_cap': 320558881.719075,
#      'last_updated': '2019-12-04T16:36:13.000Z'}}},
#   {'id': 74,
#    'name': 'Dogecoin',
#    'symbol': 'DOGE',
#    'slug': 'dogecoin',
#    'num_market_pairs': 287,
#    'date_added': '2013-12-15T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': None,
#    'circulating_supply': 122327110779.95,
#    'total_supply': 122327110779.95,
#    'platform': None,
#    'cmc_rank': 29,
#    'last_updated': '2019-12-04T16:36:04.000Z',
#    'quote': {'USD': {'price': 0.00221520201176,
#      'volume_24h': 70655772.9680591,
#      'percent_change_1h': -0.35467,
#      'percent_change_24h': -0.267869,
#      'percent_change_7d': -4.07333,
#      'market_cap': 270979261.8925336,
#      'last_updated': '2019-12-04T16:36:04.000Z'}}},
#   {'id': 1697,
#    'name': 'Basic Attention Token',
#    'symbol': 'BAT',
#    'slug': 'basic-attention-token',
#    'num_market_pairs': 161,
#    'date_added': '2017-06-01T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 1356449188.9763,
#    'total_supply': 1500000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x0d8775f648430679a709e98d2b0cb6250d2887ef'},
#    'cmc_rank': 30,
#    'last_updated': '2019-12-04T16:36:05.000Z',
#    'quote': {'USD': {'price': 0.186720850108,
#      'volume_24h': 55316475.9596866,
#      'percent_change_1h': -2.24602,
#      'percent_change_24h': -4.75209,
#      'percent_change_7d': -8.36746,
#      'market_cap': 253277345.69396186,
#      'last_updated': '2019-12-04T16:36:05.000Z'}}},
#   {'id': 3330,
#    'name': 'Paxos Standard',
#    'symbol': 'PAX',
#    'slug': 'paxos-standard',
#    'num_market_pairs': 96,
#    'date_added': '2018-09-27T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 240312689.299643,
#    'total_supply': 240312770.42,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x8e870d67f660d95d5be530380d0ec0bd388289e1'},
#    'cmc_rank': 31,
#    'last_updated': '2019-12-04T16:36:12.000Z',
#    'quote': {'USD': {'price': 1.00200458971,
#      'volume_24h': 179421410.607856,
#      'percent_change_1h': -0.33033,
#      'percent_change_24h': -0.351038,
#      'percent_change_7d': -0.103897,
#      'market_cap': 240794417.64379552,
#      'last_updated': '2019-12-04T16:36:12.000Z'}}},
#   {'id': 3296,
#    'name': 'MINDOL',
#    'symbol': 'MIN',
#    'slug': 'mindol',
#    'num_market_pairs': 13,
#    'date_added': '2019-03-29T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 141690716,
#    'total_supply': 240000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x5d64d850c8368008afb39224e92ad0dceff3cf38'},
#    'cmc_rank': 32,
#    'last_updated': '2019-12-04T16:36:11.000Z',
#    'quote': {'USD': {'price': 1.58518077601,
#      'volume_24h': 3826521.39052629,
#      'percent_change_1h': -5.94568,
#      'percent_change_24h': -36.3752,
#      'percent_change_7d': -31.8862,
#      'market_cap': 224605399.14229253,
#      'last_updated': '2019-12-04T16:36:11.000Z'}}},
#   {'id': 1437,
#    'name': 'Zcash',
#    'symbol': 'ZEC',
#    'slug': 'zcash',
#    'num_market_pairs': 223,
#    'date_added': '2016-10-29T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': None,
#    'circulating_supply': 7993318.75,
#    'total_supply': 7993318.75,
#    'platform': None,
#    'cmc_rank': 33,
#    'last_updated': '2019-12-04T16:36:05.000Z',
#    'quote': {'USD': {'price': 27.5068833386,
#      'volume_24h': 114711266.749463,
#      'percent_change_1h': -0.350058,
#      'percent_change_24h': -0.689662,
#      'percent_change_7d': -3.72333,
#      'market_cap': 219871286.344494,
#      'last_updated': '2019-12-04T16:36:05.000Z'}}},
#   {'id': 3662,
#    'name': 'HedgeTrade',
#    'symbol': 'HEDG',
#    'slug': 'hedgetrade',
#    'num_market_pairs': 8,
#    'date_added': '2019-01-03T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 288114855.057208,
#    'total_supply': 1000000000.05,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xF1290473E210b2108A85237fbCd7b6eb42Cc654F'},
#    'cmc_rank': 34,
#    'last_updated': '2019-12-04T16:36:13.000Z',
#    'quote': {'USD': {'price': 0.727333846077,
#      'volume_24h': 323265.05906101,
#      'percent_change_1h': 1.52368,
#      'percent_change_24h': 3.26411,
#      'percent_change_7d': 14.4051,
#      'market_cap': 209555685.6406765,
#      'last_updated': '2019-12-04T16:36:13.000Z'}}},
#   {'id': 1168,
#    'name': 'Decred',
#    'symbol': 'DCR',
#    'slug': 'decred',
#    'num_market_pairs': 47,
#    'date_added': '2016-02-10T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 21000000,
#    'circulating_supply': 10766306.690217,
#    'total_supply': 10766306.690217,
#    'platform': None,
#    'cmc_rank': 35,
#    'last_updated': '2019-12-04T16:36:03.000Z',
#    'quote': {'USD': {'price': 19.4347623994,
#      'volume_24h': 5831688.64849043,
#      'percent_change_1h': 0.289977,
#      'percent_change_24h': 4.45023,
#      'percent_change_7d': 7.62005,
#      'market_cap': 209240612.44343802,
#      'last_updated': '2019-12-04T16:36:03.000Z'}}},
#   {'id': 2586,
#    'name': 'Synthetix Network Token',
#    'symbol': 'SNX',
#    'slug': 'synthetix-network-token',
#    'num_market_pairs': 7,
#    'date_added': '2018-03-14T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 148341865.825791,
#    'total_supply': 154807692.307692,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xc011a72400e58ecd99ee497cf89e3775d4bd732f'},
#    'cmc_rank': 36,
#    'last_updated': '2019-12-04T16:36:07.000Z',
#    'quote': {'USD': {'price': 1.33394422468,
#      'volume_24h': 313412.624444688,
#      'percent_change_1h': 0.628374,
#      'percent_change_24h': -4.53189,
#      'percent_change_7d': -5.2903,
#      'market_cap': 197879775.19656935,
#      'last_updated': '2019-12-04T16:36:07.000Z'}}},
#   {'id': 1684,
#    'name': 'Qtum',
#    'symbol': 'QTUM',
#    'slug': 'qtum',
#    'num_market_pairs': 178,
#    'date_added': '2017-05-24T00:00:00.000Z',
#    'tags': [],
#    'max_supply': 107822406,
#    'circulating_supply': 96211400.0484598,
#    'total_supply': 101961420,
#    'platform': None,
#    'cmc_rank': 37,
#    'last_updated': '2019-12-04T16:36:05.000Z',
#    'quote': {'USD': {'price': 1.75048223304,
#      'volume_24h': 261779777.670157,
#      'percent_change_1h': -0.444568,
#      'percent_change_24h': -0.894672,
#      'percent_change_7d': 3.21973,
#      'market_cap': 168416346.40073267,
#      'last_updated': '2019-12-04T16:36:05.000Z'}}},
#   {'id': 2563,
#    'name': 'TrueUSD',
#    'symbol': 'TUSD',
#    'slug': 'trueusd',
#    'num_market_pairs': 147,
#    'date_added': '2018-03-06T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 157539665.74,
#    'total_supply': 157539665.74,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x0000000000085d4780B73119b644AE5ecd22b376'},
#    'cmc_rank': 38,
#    'last_updated': '2019-12-04T16:36:08.000Z',
#    'quote': {'USD': {'price': 0.997874956261,
#      'volume_24h': 194345553.754787,
#      'percent_change_1h': -0.255736,
#      'percent_change_24h': -0.313133,
#      'percent_change_7d': -0.563893,
#      'market_cap': 157204887.05967507,
#      'last_updated': '2019-12-04T16:36:08.000Z'}}},
#   {'id': 1896,
#    'name': '0x',
#    'symbol': 'ZRX',
#    'slug': '0x',
#    'num_market_pairs': 175,
#    'date_added': '2017-08-16T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 602160071.148669,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xe41d2489571d322189246dafa5ebde1f4699f498'},
#    'cmc_rank': 39,
#    'last_updated': '2019-12-04T16:36:05.000Z',
#    'quote': {'USD': {'price': 0.241180787658,
#      'volume_24h': 13300703.0495495,
#      'percent_change_1h': -0.419261,
#      'percent_change_24h': -2.85334,
#      'percent_change_7d': -5.42967,
#      'market_cap': 145229440.2558333,
#      'last_updated': '2019-12-04T16:36:05.000Z'}}},
#   {'id': 2585,
#    'name': 'Centrality',
#    'symbol': 'CENNZ',
#    'slug': 'centrality',
#    'num_market_pairs': 2,
#    'date_added': '2018-03-13T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 1069176371.64951,
#    'total_supply': 1200000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1122b6a0e00dce0563082b6e2953f3a943855c1f'},
#    'cmc_rank': 40,
#    'last_updated': '2019-12-04T16:36:07.000Z',
#    'quote': {'USD': {'price': 0.13564660852,
#      'volume_24h': 410097.854350327,
#      'percent_change_1h': 0.538326,
#      'percent_change_24h': -1.40615,
#      'percent_change_7d': -4.39681,
#      'market_cap': 145030148.7239751,
#      'last_updated': '2019-12-04T16:36:07.000Z'}}},
#   {'id': 2577,
#    'name': 'Ravencoin',
#    'symbol': 'RVN',
#    'slug': 'ravencoin',
#    'num_market_pairs': 45,
#    'date_added': '2018-03-10T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 21000000000,
#    'circulating_supply': 4996025000,
#    'total_supply': 4996025000,
#    'platform': None,
#    'cmc_rank': 41,
#    'last_updated': '2019-12-04T16:36:08.000Z',
#    'quote': {'USD': {'price': 0.0277622963492,
#      'volume_24h': 41534577.5000428,
#      'percent_change_1h': 1.49069,
#      'percent_change_24h': 3.99907,
#      'percent_change_7d': 24.2791,
#      'market_cap': 138701126.61801192,
#      'last_updated': '2019-12-04T16:36:08.000Z'}}},
#   {'id': 2682,
#    'name': 'Holo',
#    'symbol': 'HOT',
#    'slug': 'holo',
#    'num_market_pairs': 62,
#    'date_added': '2018-04-29T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 161496951785.847,
#    'total_supply': 177619433541.141,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6c6ee5e31d828de241282b9606c8e98ea48526e2'},
#    'cmc_rank': 42,
#    'last_updated': '2019-12-04T16:36:08.000Z',
#    'quote': {'USD': {'price': 0.000780709888626,
#      'volume_24h': 6165618.86856297,
#      'percent_change_1h': -0.275277,
#      'percent_change_24h': -0.105581,
#      'percent_change_7d': -4.52278,
#      'market_cap': 126082267.2421671,
#      'last_updated': '2019-12-04T16:36:08.000Z'}}},
#   {'id': 4030,
#    'name': 'Algorand',
#    'symbol': 'ALGO',
#    'slug': 'algorand',
#    'num_market_pairs': 60,
#    'date_added': '2019-06-20T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': None,
#    'circulating_supply': 454807121.638888,
#    'total_supply': 2986078964.63889,
#    'platform': None,
#    'cmc_rank': 43,
#    'last_updated': '2019-12-04T16:36:14.000Z',
#    'quote': {'USD': {'price': 0.274427940565,
#      'volume_24h': 128966651.089679,
#      'percent_change_1h': -0.643783,
#      'percent_change_24h': -2.73423,
#      'percent_change_7d': 21.9396,
#      'market_cap': 124811781.74565546,
#      'last_updated': '2019-12-04T16:36:14.000Z'}}},
#   {'id': 2830,
#    'name': 'Seele',
#    'symbol': 'SEELE',
#    'slug': 'seele',
#    'num_market_pairs': 14,
#    'date_added': '2018-05-31T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 699562206.289478,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xb1eef147028e9f480dbc5ccaa3277d417d1b85f0'},
#    'cmc_rank': 44,
#    'last_updated': '2019-12-04T16:36:08.000Z',
#    'quote': {'USD': {'price': 0.162092385676,
#      'volume_24h': 52943795.0669562,
#      'percent_change_1h': -1.03306,
#      'percent_change_24h': -0.197939,
#      'percent_change_7d': 21.3872,
#      'market_cap': 113393706.94622754,
#      'last_updated': '2019-12-04T16:36:08.000Z'}}},
#   {'id': 1104,
#    'name': 'Augur',
#    'symbol': 'REP',
#    'slug': 'augur',
#    'num_market_pairs': 67,
#    'date_added': '2015-10-27T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 11000000,
#    'total_supply': 11000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1985365e9f78359a9b6ad760e32412f4a445e862'},
#    'cmc_rank': 45,
#    'last_updated': '2019-12-04T16:36:03.000Z',
#    'quote': {'USD': {'price': 10.1285916838,
#      'volume_24h': 6499661.77368618,
#      'percent_change_1h': -1.01965,
#      'percent_change_24h': -3.10519,
#      'percent_change_7d': -9.12502,
#      'market_cap': 111414508.5218,
#      'last_updated': '2019-12-04T16:36:03.000Z'}}},
#   {'id': 1567,
#    'name': 'Nano',
#    'symbol': 'NANO',
#    'slug': 'nano',
#    'num_market_pairs': 50,
#    'date_added': '2017-03-06T00:00:00.000Z',
#    'tags': [],
#    'max_supply': 133248297.197,
#    'circulating_supply': 133248297.197,
#    'total_supply': 133248297.197,
#    'platform': None,
#    'cmc_rank': 46,
#    'last_updated': '2019-12-04T16:36:04.000Z',
#    'quote': {'USD': {'price': 0.823947097385,
#      'volume_24h': 2867265.70622054,
#      'percent_change_1h': -0.526676,
#      'percent_change_24h': -2.58119,
#      'percent_change_7d': 0.261633,
#      'market_cap': 109789547.70696199,
#      'last_updated': '2019-12-04T16:36:04.000Z'}}},
#   {'id': 2083,
#    'name': 'Bitcoin Gold',
#    'symbol': 'BTG',
#    'slug': 'bitcoin-gold',
#    'num_market_pairs': 84,
#    'date_added': '2017-10-23T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 21000000,
#    'circulating_supply': 17513923.589,
#    'total_supply': 17513923.589,
#    'platform': None,
#    'cmc_rank': 47,
#    'last_updated': '2019-12-04T16:36:05.000Z',
#    'quote': {'USD': {'price': 6.02650627192,
#      'volume_24h': 12096730.4812303,
#      'percent_change_1h': -0.271308,
#      'percent_change_24h': -0.363029,
#      'percent_change_7d': -6.30972,
#      'market_cap': 105547770.35503614,
#      'last_updated': '2019-12-04T16:36:05.000Z'}}},
#   {'id': 1808,
#    'name': 'OmiseGO',
#    'symbol': 'OMG',
#    'slug': 'omisego',
#    'num_market_pairs': 203,
#    'date_added': '2017-07-14T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 140245398.245133,
#    'total_supply': 140245398.245133,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xd26114cd6EE289AccF82350c8d8487fedB8A0C07'},
#    'cmc_rank': 48,
#    'last_updated': '2019-12-04T16:36:06.000Z',
#    'quote': {'USD': {'price': 0.743589442477,
#      'volume_24h': 44522167.5588421,
#      'percent_change_1h': -0.306756,
#      'percent_change_24h': 0.533385,
#      'percent_change_7d': -2.97368,
#      'market_cap': 104284997.49106328,
#      'last_updated': '2019-12-04T16:36:06.000Z'}}},
#   {'id': 3704,
#    'name': 'V Systems',
#    'symbol': 'VSYS',
#    'slug': 'v-systems',
#    'num_market_pairs': 33,
#    'date_added': '2019-03-05T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 1866948769,
#    'total_supply': 3781807233,
#    'platform': None,
#    'cmc_rank': 49,
#    'last_updated': '2019-12-04T16:36:13.000Z',
#    'quote': {'USD': {'price': 0.0526242411746,
#      'volume_24h': 2514676.38452352,
#      'percent_change_1h': -0.340671,
#      'percent_change_24h': 2.90753,
#      'percent_change_7d': 2.24837,
#      'market_cap': 98246762.2804786,
#      'last_updated': '2019-12-04T16:36:13.000Z'}}},
#   {'id': 3437,
#    'name': 'ABBC Coin',
#    'symbol': 'ABBC',
#    'slug': 'abbc-coin',
#    'num_market_pairs': 39,
#    'date_added': '2018-10-12T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': None,
#    'circulating_supply': 556626634.357622,
#    'total_supply': 1004488460.0178,
#    'platform': None,
#    'cmc_rank': 50,
#    'last_updated': '2019-12-04T16:36:12.000Z',
#    'quote': {'USD': {'price': 0.173388577832,
#      'volume_24h': 42476961.2864744,
#      'percent_change_1h': 0.294791,
#      'percent_change_24h': 0.454593,
#      'percent_change_7d': -4.49974,
#      'market_cap': 96512700.51468076,
#      'last_updated': '2019-12-04T16:36:12.000Z'}}},
#   {'id': 4195,
#    'name': 'FTX Token',
#    'symbol': 'FTT',
#    'slug': 'ftx-token',
#    'num_market_pairs': 13,
#    'date_added': '2019-07-31T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 52288488.9327723,
#    'total_supply': 348160825,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9'},
#    'cmc_rank': 51,
#    'last_updated': '2019-12-04T16:36:14.000Z',
#    'quote': {'USD': {'price': 1.80706193342,
#      'volume_24h': 10236995.6747426,
#      'percent_change_1h': 0.0158115,
#      'percent_change_24h': 15.5774,
#      'percent_change_7d': 26.3593,
#      'market_cap': 94488537.90646578,
#      'last_updated': '2019-12-04T16:36:14.000Z'}}},
#   {'id': 3351,
#    'name': 'ZB',
#    'symbol': 'ZB',
#    'slug': 'zb',
#    'num_market_pairs': 10,
#    'date_added': '2018-09-27T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 463288810,
#    'total_supply': 2100000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xbd0793332e9fb844a52a205a233ef27a5b34b927'},
#    'cmc_rank': 52,
#    'last_updated': '2019-12-04T16:36:12.000Z',
#    'quote': {'USD': {'price': 0.195971650464,
#      'volume_24h': 227528553.374727,
#      'percent_change_1h': -0.241843,
#      'percent_change_24h': -0.815028,
#      'percent_change_7d': 2.42321,
#      'market_cap': 90791472.73720251,
#      'last_updated': '2019-12-04T16:36:12.000Z'}}},
#   {'id': 109,
#    'name': 'DigiByte',
#    'symbol': 'DGB',
#    'slug': 'digibyte',
#    'num_market_pairs': 78,
#    'date_added': '2014-02-06T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 21000000000,
#    'circulating_supply': 12562613042.9027,
#    'total_supply': 12562613042.9027,
#    'platform': None,
#    'cmc_rank': 53,
#    'last_updated': '2019-12-04T16:36:02.000Z',
#    'quote': {'USD': {'price': 0.00675466069609,
#      'volume_24h': 1095033.97759961,
#      'percent_change_1h': 0.0146473,
#      'percent_change_24h': 1.7177,
#      'percent_change_7d': -0.565517,
#      'market_cap': 84856188.56108247,
#      'last_updated': '2019-12-04T16:36:02.000Z'}}},
#   {'id': 1214,
#    'name': 'Lisk',
#    'symbol': 'LSK',
#    'slug': 'lisk',
#    'num_market_pairs': 61,
#    'date_added': '2016-04-06T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 121839598.912821,
#    'total_supply': 136860500,
#    'platform': None,
#    'cmc_rank': 54,
#    'last_updated': '2019-12-04T16:36:03.000Z',
#    'quote': {'USD': {'price': 0.676219238919,
#      'volume_24h': 813600.652982728,
#      'percent_change_1h': 0.04324,
#      'percent_change_24h': 0.376941,
#      'percent_change_7d': 0.158777,
#      'market_cap': 82390280.84702404,
#      'last_updated': '2019-12-04T16:36:03.000Z'}}},
#   {'id': 1521,
#    'name': 'Komodo',
#    'symbol': 'KMD',
#    'slug': 'komodo',
#    'num_market_pairs': 23,
#    'date_added': '2017-02-05T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 200000000,
#    'circulating_supply': 117291605.52593,
#    'total_supply': 117291605.52593,
#    'platform': None,
#    'cmc_rank': 55,
#    'last_updated': '2019-12-04T16:36:04.000Z',
#    'quote': {'USD': {'price': 0.690566953721,
#      'volume_24h': 3853716.42771383,
#      'percent_change_1h': -0.31013,
#      'percent_change_24h': -4.03688,
#      'percent_change_7d': 0.456191,
#      'market_cap': 80997706.72508669,
#      'last_updated': '2019-12-04T16:36:04.000Z'}}},
#   {'id': 2453,
#    'name': 'EDUCare',
#    'symbol': 'EKT',
#    'slug': 'educare',
#    'num_market_pairs': 6,
#    'date_added': '2018-01-23T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 1000000000,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x4ecdb6385f3db3847f9c4a9bf3f9917bb27a5452'},
#    'cmc_rank': 56,
#    'last_updated': '2019-12-04T16:36:07.000Z',
#    'quote': {'USD': {'price': 0.0807324289302,
#      'volume_24h': 4268068.91082808,
#      'percent_change_1h': 0.900802,
#      'percent_change_24h': -1.6036,
#      'percent_change_7d': -23.3941,
#      'market_cap': 80732428.9302,
#      'last_updated': '2019-12-04T16:36:07.000Z'}}},
#   {'id': 2087,
#    'name': 'KuCoin Shares',
#    'symbol': 'KCS',
#    'slug': 'kucoin-shares',
#    'num_market_pairs': 15,
#    'date_added': '2017-10-24T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 82363551,
#    'total_supply': 172363551,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x039b5649a59967e3e936d7471f9c3700100ee1ab'},
#    'cmc_rank': 57,
#    'last_updated': '2019-12-04T16:36:05.000Z',
#    'quote': {'USD': {'price': 0.972475607798,
#      'volume_24h': 5117243.66981665,
#      'percent_change_1h': 0.492771,
#      'percent_change_24h': -0.282975,
#      'percent_change_7d': -0.0572361,
#      'market_cap': 80096544.31912658,
#      'last_updated': '2019-12-04T16:36:05.000Z'}}},
#   {'id': 1866,
#    'name': 'Bytom',
#    'symbol': 'BTM',
#    'slug': 'bytom',
#    'num_market_pairs': 50,
#    'date_added': '2017-08-08T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': None,
#    'circulating_supply': 1002499275,
#    'total_supply': 1407000000,
#    'platform': None,
#    'cmc_rank': 58,
#    'last_updated': '2019-12-04T16:36:04.000Z',
#    'quote': {'USD': {'price': 0.0796857187681,
#      'volume_24h': 13657220.4920747,
#      'percent_change_1h': 0.112484,
#      'percent_change_24h': -0.958847,
#      'percent_change_7d': 9.15675,
#      'market_cap': 79884875.29287414,
#      'last_updated': '2019-12-04T16:36:04.000Z'}}},
#   {'id': 3890,
#    'name': 'Matic Network',
#    'symbol': 'MATIC',
#    'slug': 'matic-network',
#    'num_market_pairs': 31,
#    'date_added': '2019-04-28T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 2539297092,
#    'total_supply': 10000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0'},
#    'cmc_rank': 59,
#    'last_updated': '2019-12-04T16:36:14.000Z',
#    'quote': {'USD': {'price': 0.0314022588853,
#      'volume_24h': 63307955.7168448,
#      'percent_change_1h': -0.671559,
#      'percent_change_24h': 7.41455,
#      'percent_change_7d': 32.1212,
#      'market_cap': 79739664.66967346,
#      'last_updated': '2019-12-04T16:36:14.000Z'}}},
#   {'id': 4172,
#    'name': 'LUNA',
#    'symbol': 'LUNA',
#    'slug': 'luna',
#    'num_market_pairs': 10,
#    'date_added': '2019-07-26T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 287765804.430561,
#    'total_supply': 995859074.224591,
#    'platform': None,
#    'cmc_rank': 60,
#    'last_updated': '2019-12-04T16:36:14.000Z',
#    'quote': {'USD': {'price': 0.250773439127,
#      'volume_24h': 554167.862050399,
#      'percent_change_1h': 0.0382519,
#      'percent_change_24h': -3.96286,
#      'percent_change_7d': 11.2668,
#      'market_cap': 72164020.44019948,
#      'last_updated': '2019-12-04T16:36:14.000Z'}}},
#   {'id': 2222,
#    'name': 'Bitcoin Diamond',
#    'symbol': 'BCD',
#    'slug': 'bitcoin-diamond',
#    'num_market_pairs': 25,
#    'date_added': '2017-11-24T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 210000000,
#    'circulating_supply': 186492897.953,
#    'total_supply': 189492897.953,
#    'platform': None,
#    'cmc_rank': 61,
#    'last_updated': '2019-12-04T16:36:05.000Z',
#    'quote': {'USD': {'price': 0.377089305526,
#      'volume_24h': 2350950.30791537,
#      'percent_change_1h': 1.93151,
#      'percent_change_24h': 1.68383,
#      'percent_change_7d': -2.20616,
#      'market_cap': 70324477.37462796,
#      'last_updated': '2019-12-04T16:36:05.000Z'}}},
#   {'id': 4279,
#    'name': 'Swipe',
#    'symbol': 'SXP',
#    'slug': 'swipe',
#    'num_market_pairs': 9,
#    'date_added': '2019-08-26T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 61135911.166,
#    'total_supply': 300000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x8ce9137d39326ad0cd6491fb5cc0cba0e089b6a9'},
#    'cmc_rank': 62,
#    'last_updated': '2019-12-04T16:36:15.000Z',
#    'quote': {'USD': {'price': 1.1488104308,
#      'volume_24h': 14976554.8097437,
#      'percent_change_1h': -1.03055,
#      'percent_change_24h': -1.52487,
#      'percent_change_7d': -2.39334,
#      'market_cap': 70233572.44396299,
#      'last_updated': '2019-12-04T16:36:15.000Z'}}},
#   {'id': 2405,
#    'name': 'IOST',
#    'symbol': 'IOST',
#    'slug': 'iostoken',
#    'num_market_pairs': 84,
#    'date_added': '2018-01-16T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 12013965608.8475,
#    'total_supply': 21000000000,
#    'platform': None,
#    'cmc_rank': 63,
#    'last_updated': '2019-12-04T16:36:07.000Z',
#    'quote': {'USD': {'price': 0.00584295473103,
#      'volume_24h': 32507132.3426002,
#      'percent_change_1h': -0.687879,
#      'percent_change_24h': -2.2986,
#      'percent_change_7d': 9.27938,
#      'market_cap': 70197057.1926472,
#      'last_updated': '2019-12-04T16:36:07.000Z'}}},
#   {'id': 2099,
#    'name': 'ICON',
#    'symbol': 'ICX',
#    'slug': 'icon',
#    'num_market_pairs': 63,
#    'date_added': '2017-10-27T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 507800208.068532,
#    'total_supply': 800460000,
#    'platform': None,
#    'cmc_rank': 64,
#    'last_updated': '2019-12-04T16:36:05.000Z',
#    'quote': {'USD': {'price': 0.1331767964,
#      'volume_24h': 4381198.49027548,
#      'percent_change_1h': -0.0502315,
#      'percent_change_24h': -0.176236,
#      'percent_change_7d': -1.57754,
#      'market_cap': 67627204.92182052,
#      'last_updated': '2019-12-04T16:36:05.000Z'}}},
#   {'id': 3718,
#    'name': 'BitTorrent',
#    'symbol': 'BTT',
#    'slug': 'bittorrent',
#    'num_market_pairs': 129,
#    'date_added': '2019-01-31T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 212116500000,
#    'total_supply': 990000000000,
#    'platform': {'id': 1958,
#     'name': 'TRON',
#     'symbol': 'TRX',
#     'slug': 'tron',
#     'token_address': '1002000'},
#    'cmc_rank': 65,
#    'last_updated': '2019-12-04T16:36:13.000Z',
#    'quote': {'USD': {'price': 0.000312518066502,
#      'volume_24h': 55012794.186286,
#      'percent_change_1h': 1.45447,
#      'percent_change_24h': 0.495913,
#      'percent_change_7d': 0.283266,
#      'market_cap': 66290238.453171484,
#      'last_updated': '2019-12-04T16:36:13.000Z'}}},
#   {'id': 2416,
#    'name': 'THETA',
#    'symbol': 'THETA',
#    'slug': 'theta',
#    'num_market_pairs': 30,
#    'date_added': '2018-01-17T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 870502690,
#    'total_supply': 1000000000,
#    'platform': None,
#    'cmc_rank': 66,
#    'last_updated': '2019-12-04T16:36:06.000Z',
#    'quote': {'USD': {'price': 0.0746252491077,
#      'volume_24h': 1483598.89790802,
#      'percent_change_1h': 0.0429065,
#      'percent_change_24h': -3.73485,
#      'percent_change_7d': -2.69765,
#      'market_cap': 64961480.090172954,
#      'last_updated': '2019-12-04T16:36:06.000Z'}}},
#   {'id': 693,
#    'name': 'Verge',
#    'symbol': 'XVG',
#    'slug': 'verge',
#    'num_market_pairs': 59,
#    'date_added': '2014-10-25T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 16555000000,
#    'circulating_supply': 16087461059.1206,
#    'total_supply': 16087461059.1206,
#    'platform': None,
#    'cmc_rank': 67,
#    'last_updated': '2019-12-04T16:36:03.000Z',
#    'quote': {'USD': {'price': 0.00397347077449,
#      'volume_24h': 2616149.37170465,
#      'percent_change_1h': -0.323756,
#      'percent_change_24h': 2.35405,
#      'percent_change_7d': 0.631627,
#      'market_cap': 63923056.35416164,
#      'last_updated': '2019-12-04T16:36:03.000Z'}}},
#   {'id': 1776,
#    'name': 'MCO',
#    'symbol': 'MCO',
#    'slug': 'crypto-com',
#    'num_market_pairs': 57,
#    'date_added': '2017-07-03T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 15793831.0949625,
#    'total_supply': 31587682.3632061,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xb63b606ac810a52cca15e44bb630fd42d8d1d83d'},
#    'cmc_rank': 68,
#    'last_updated': '2019-12-04T16:36:04.000Z',
#    'quote': {'USD': {'price': 4.04537844699,
#      'volume_24h': 14560742.8964686,
#      'percent_change_1h': -0.00174857,
#      'percent_change_24h': 2.98552,
#      'percent_change_7d': 2.7674,
#      'market_cap': 63892023.90696177,
#      'last_updated': '2019-12-04T16:36:04.000Z'}}},
#   {'id': 1042,
#    'name': 'Siacoin',
#    'symbol': 'SC',
#    'slug': 'siacoin',
#    'num_market_pairs': 38,
#    'date_added': '2015-08-26T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': None,
#    'circulating_supply': 41817047634,
#    'total_supply': 41817047634,
#    'platform': None,
#    'cmc_rank': 69,
#    'last_updated': '2019-12-04T16:36:03.000Z',
#    'quote': {'USD': {'price': 0.00152387701017,
#      'volume_24h': 1700377.2098056,
#      'percent_change_1h': -0.919597,
#      'percent_change_24h': -2.76991,
#      'percent_change_7d': -2.78764,
#      'market_cap': 63724037.52263639,
#      'last_updated': '2019-12-04T16:36:03.000Z'}}},
#   {'id': 3155,
#    'name': 'Quant',
#    'symbol': 'QNT',
# ...
#    'date_added': '2014-04-28T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 452552412,
#    'total_supply': 452552412,
#    'platform': {'id': 83,
#     'name': 'Omni',
#     'symbol': 'OMNI',
#     'slug': 'omni',
#     'token_address': '3'},
#    'cmc_rank': 79,
#    'last_updated': '2019-12-04T16:36:02.000Z',
#    'quote': {'USD': {'price': 0.121739314643,
#      'volume_24h': 267842.160159176,
#      'percent_change_1h': 0.0142648,
#      'percent_change_24h': -2.44529,
#      'percent_change_7d': 7.82965,
#      'market_cap': 55093420.47691657,
#      'last_updated': '2019-12-04T16:36:02.000Z'}}},
#   {'id': 1903,
#    'name': 'HyperCash',
#    'symbol': 'HC',
#    'slug': 'hypercash',
#    'num_market_pairs': 32,
#    'date_added': '2017-08-20T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 84000000,
#    'circulating_supply': 44445635.425052,
#    'total_supply': 44445635.425052,
#    'platform': None,
#    'cmc_rank': 80,
#    'last_updated': '2019-12-04T16:36:04.000Z',
#    'quote': {'USD': {'price': 1.23034883887,
#      'volume_24h': 2386162.37749436,
#      'percent_change_1h': -0.601742,
#      'percent_change_24h': 0.122925,
#      'percent_change_7d': 4.19336,
#      'market_cap': 54683635.938052066,
#      'last_updated': '2019-12-04T16:36:04.000Z'}}},
#   {'id': 2694,
#    'name': 'Nexo',
#    'symbol': 'NEXO',
#    'slug': 'nexo',
#    'num_market_pairs': 21,
#    'date_added': '2018-05-01T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 560000011,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xb62132e35a6c13ee1ee0f84dc5d40bad8d815206'},
#    'cmc_rank': 81,
#    'last_updated': '2019-12-04T16:36:08.000Z',
#    'quote': {'USD': {'price': 0.095611753711,
#      'volume_24h': 8679121.25967373,
#      'percent_change_1h': -0.13887,
#      'percent_change_24h': 2.57096,
#      'percent_change_7d': 3.04058,
#      'market_cap': 53542583.129889295,
#      'last_updated': '2019-12-04T16:36:08.000Z'}}},
#   {'id': 2130,
#    'name': 'Enjin Coin',
#    'symbol': 'ENJ',
#    'slug': 'enjin-coin',
#    'num_market_pairs': 52,
#    'date_added': '2017-11-01T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 784764641.564264,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c'},
#    'cmc_rank': 82,
#    'last_updated': '2019-12-04T16:36:05.000Z',
#    'quote': {'USD': {'price': 0.0642400668081,
#      'volume_24h': 5878966.41053884,
#      'percent_change_1h': 5.49675,
#      'percent_change_24h': 7.53103,
#      'percent_change_7d': 13.2904,
#      'market_cap': 50413333.00272297,
#      'last_updated': '2019-12-04T16:36:05.000Z'}}},
#   {'id': 1320,
#    'name': 'Ardor',
#    'symbol': 'ARDR',
#    'slug': 'ardor',
#    'num_market_pairs': 26,
#    'date_added': '2016-07-23T00:00:00.000Z',
#    'tags': [],
#    'max_supply': 998999495,
#    'circulating_supply': 998999495,
#    'total_supply': 998999495,
#    'platform': None,
#    'cmc_rank': 83,
#    'last_updated': '2019-12-04T16:36:03.000Z',
#    'quote': {'USD': {'price': 0.0485879584576,
#      'volume_24h': 2204025.35369649,
#      'percent_change_1h': -0.0384577,
#      'percent_change_24h': -2.45627,
#      'percent_change_7d': -5.42922,
#      'market_cap': 48539345.96222338,
#      'last_updated': '2019-12-04T16:36:03.000Z'}}},
#   {'id': 1700,
#    'name': 'Aeternity',
#    'symbol': 'AE',
#    'slug': 'aeternity',
#    'num_market_pairs': 51,
#    'date_added': '2017-06-01T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': None,
#    'circulating_supply': 293267869.5,
#    'total_supply': 339088813.49932,
#    'platform': None,
#    'cmc_rank': 84,
#    'last_updated': '2019-12-04T16:36:04.000Z',
#    'quote': {'USD': {'price': 0.162236603693,
#      'volume_24h': 35934708.9001026,
#      'percent_change_1h': -0.544289,
#      'percent_change_24h': 1.11816,
#      'percent_change_7d': 1.87294,
#      'market_cap': 47578783.11996194,
#      'last_updated': '2019-12-04T16:36:04.000Z'}}},
#   {'id': 1637,
#    'name': 'iExec RLC',
#    'symbol': 'RLC',
#    'slug': 'rlc',
#    'num_market_pairs': 17,
#    'date_added': '2017-04-20T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 80070793.2387674,
#    'total_supply': 86999784.9868455,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x607f4c5bb672230e8672085532f7e901544a7375'},
#    'cmc_rank': 85,
#    'last_updated': '2019-12-04T16:36:04.000Z',
#    'quote': {'USD': {'price': 0.563393437528,
#      'volume_24h': 901257.712904325,
#      'percent_change_1h': 1.11006,
#      'percent_change_24h': 1.90775,
#      'percent_change_7d': -12.0374,
#      'market_cap': 45111359.44838291,
#      'last_updated': '2019-12-04T16:36:04.000Z'}}},
#   {'id': 1230,
#    'name': 'Steem',
#    'symbol': 'STEEM',
#    'slug': 'steem',
#    'num_market_pairs': 33,
#    'date_added': '2016-04-18T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 352994220.534,
#    'total_supply': 369968314.534,
#    'platform': None,
#    'cmc_rank': 86,
#    'last_updated': '2019-12-04T16:36:03.000Z',
#    'quote': {'USD': {'price': 0.122440688215,
#      'volume_24h': 517367.00288532,
#      'percent_change_1h': -0.688754,
#      'percent_change_24h': 1.33647,
#      'percent_change_7d': -10.0484,
#      'market_cap': 43220855.29810044,
#      'last_updated': '2019-12-04T16:36:03.000Z'}}},
#   {'id': 1698,
#    'name': 'Horizen',
#    'symbol': 'ZEN',
#    'slug': 'horizen',
#    'num_market_pairs': 34,
#    'date_added': '2017-06-01T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 21000000,
#    'circulating_supply': 7905250,
#    'total_supply': 7905250,
#    'platform': None,
#    'cmc_rank': 87,
#    'last_updated': '2019-12-04T16:36:04.000Z',
#    'quote': {'USD': {'price': 5.23771178959,
#      'volume_24h': 583246.603326011,
#      'percent_change_1h': -0.300885,
#      'percent_change_24h': -2.30646,
#      'percent_change_7d': -6.49671,
#      'market_cap': 41405421.12465634,
#      'last_updated': '2019-12-04T16:36:04.000Z'}}},
#   {'id': 4066,
#    'name': 'Chiliz',
#    'symbol': 'CHZ',
#    'slug': 'chiliz',
#    'num_market_pairs': 10,
#    'date_added': '2019-07-01T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 3763769182,
#    'total_supply': 8888888888,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x3506424f91fd33084466f402d5d97f05f8e3b4af'},
#    'cmc_rank': 88,
#    'last_updated': '2019-12-04T16:36:14.000Z',
#    'quote': {'USD': {'price': 0.0109574193433,
#      'volume_24h': 3297276.47135413,
#      'percent_change_1h': -1.7242,
#      'percent_change_24h': -2.32964,
#      'percent_change_7d': -8.73731,
#      'market_cap': 41241197.238563225,
#      'last_updated': '2019-12-04T16:36:14.000Z'}}},
#   {'id': 3724,
#    'name': 'SOLVE',
#    'symbol': 'SOLVE',
#    'slug': 'solve',
#    'num_market_pairs': 9,
#    'date_added': '2019-02-04T00:00:00.000Z',
#    'tags': [],
#    'max_supply': 1000000000,
#    'circulating_supply': 327424138.235688,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x446c9033e7516d820cc9a2ce2d0b7328b579406f'},
#    'cmc_rank': 89,
#    'last_updated': '2019-12-04T16:36:13.000Z',
#    'quote': {'USD': {'price': 0.11930368153,
#      'volume_24h': 1291672.72350014,
#      'percent_change_1h': 0.235132,
#      'percent_change_24h': -2.76696,
#      'percent_change_7d': 2.87374,
#      'market_cap': 39062905.11330521,
#      'last_updated': '2019-12-04T16:36:13.000Z'}}},
#   {'id': 3773,
#    'name': 'Fetch.ai',
#    'symbol': 'FET',
#    'slug': 'fetch',
#    'num_market_pairs': 28,
#    'date_added': '2019-03-02T00:00:00.000Z',
#    'tags': [],
#    'max_supply': 1152997575,
#    'circulating_supply': 654713475.284661,
#    'total_supply': 1152997575,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1d287cc25dad7ccaf76a26bc660c5f7c8e2a05bd'},
#    'cmc_rank': 90,
#    'last_updated': '2019-12-04T16:36:13.000Z',
#    'quote': {'USD': {'price': 0.0594803405083,
#      'volume_24h': 23850970.5474043,
#      'percent_change_1h': -0.617876,
#      'percent_change_24h': -1.94214,
#      'percent_change_7d': 20.4014,
#      'market_cap': 38942580.445304096,
#      'last_updated': '2019-12-04T16:36:13.000Z'}}},
#   {'id': 1759,
#    'name': 'Status',
#    'symbol': 'SNT',
#    'slug': 'status',
#    'num_market_pairs': 86,
#    'date_added': '2017-06-28T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 3470483788,
#    'total_supply': 6804870174,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x744d70fdbe2ba4cf95131626614a1763df805b9e'},
#    'cmc_rank': 91,
#    'last_updated': '2019-12-04T16:36:04.000Z',
#    'quote': {'USD': {'price': 0.0109188114736,
#      'volume_24h': 181175128.019705,
#      'percent_change_1h': -0.384861,
#      'percent_change_24h': 0.700411,
#      'percent_change_7d': 2.5179,
#      'market_cap': 37893558.20335719,
#      'last_updated': '2019-12-04T16:36:04.000Z'}}},
#   {'id': 2137,
#    'name': 'Electroneum',
#    'symbol': 'ETN',
#    'slug': 'electroneum',
#    'num_market_pairs': 20,
#    'date_added': '2017-11-02T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 21000000000,
#    'circulating_supply': 9909585856.13,
#    'total_supply': 9909585856.13,
#    'platform': None,
#    'cmc_rank': 92,
#    'last_updated': '2019-12-04T16:36:05.000Z',
#    'quote': {'USD': {'price': 0.0038170273796,
#      'volume_24h': 160257.70126641,
#      'percent_change_1h': -0.558145,
#      'percent_change_24h': 0.731417,
#      'percent_change_7d': 8.26558,
#      'market_cap': 37825160.53334511,
#      'last_updated': '2019-12-04T16:36:05.000Z'}}},
#   {'id': 2603,
#    'name': 'Pundi X',
#    'symbol': 'NPXS',
#    'slug': 'pundi-x',
#    'num_market_pairs': 69,
#    'date_added': '2018-03-22T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 234562817276.377,
#    'total_supply': 259810708832.63,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xa15c7ebe1f07caf6bff097d8a589fb8ac49ae5b3'},
#    'cmc_rank': 93,
#    'last_updated': '2019-12-04T16:36:08.000Z',
#    'quote': {'USD': {'price': 0.000157625700025,
#      'volume_24h': 806819.408862971,
#      'percent_change_1h': 0.231005,
#      'percent_change_24h': -0.712647,
#      'percent_change_7d': 6.08091,
#      'market_cap': 36973128.273025095,
#      'last_updated': '2019-12-04T16:36:08.000Z'}}},
#   {'id': 2044,
#    'name': 'Enigma',
#    'symbol': 'ENG',
#    'slug': 'enigma',
#    'num_market_pairs': 27,
#    'date_added': '2017-10-13T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 74836171.09,
#    'total_supply': 150000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xf0ee6b27b759c9893ce4f094b49ad28fd15a23e4'},
#    'cmc_rank': 94,
#    'last_updated': '2019-12-04T16:36:05.000Z',
#    'quote': {'USD': {'price': 0.488601196609,
#      'volume_24h': 834250.93198595,
#      'percent_change_1h': -1.31478,
#      'percent_change_24h': 3.64298,
#      'percent_change_7d': -7.91726,
#      'market_cap': 36565042.74420985,
#      'last_updated': '2019-12-04T16:36:05.000Z'}}},
#   {'id': 2772,
#    'name': 'Digitex Futures',
#    'symbol': 'DGTX',
#    'slug': 'digitex-futures',
#    'num_market_pairs': 7,
#    'date_added': '2018-05-23T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 786260027.490069,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1c83501478f1320977047008496dacbd60bb15ef'},
#    'cmc_rank': 95,
#    'last_updated': '2019-12-04T16:36:08.000Z',
#    'quote': {'USD': {'price': 0.0463093901184,
#      'volume_24h': 1041958.28779252,
#      'percent_change_1h': -0.401797,
#      'percent_change_24h': -0.445117,
#      'percent_change_7d': -7.34725,
#      'market_cap': 36411222.34754151,
#      'last_updated': '2019-12-04T16:36:08.000Z'}}},
#   {'id': 1455,
#    'name': 'Golem',
#    'symbol': 'GNT',
#    'slug': 'golem-network-tokens',
#    'num_market_pairs': 98,
#    'date_added': '2016-11-18T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 980050000,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xa74476443119A942dE498590Fe1f2454d7D4aC0d'},
#    'cmc_rank': 96,
#    'last_updated': '2019-12-04T16:36:04.000Z',
#    'quote': {'USD': {'price': 0.0371005105055,
#      'volume_24h': 1906395.38271396,
#      'percent_change_1h': -0.078543,
#      'percent_change_24h': -2.64826,
#      'percent_change_7d': -0.951256,
#      'market_cap': 36360355.320915274,
#      'last_updated': '2019-12-04T16:36:04.000Z'}}},
#   {'id': 3617,
#    'name': 'ILCoin',
#    'symbol': 'ILC',
#    'slug': 'ilcoin',
#    'num_market_pairs': 26,
#    'date_added': '2018-11-26T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 2500000000,
#    'circulating_supply': 345442487.370894,
#    'total_supply': 1299138907.43547,
#    'platform': None,
#    'cmc_rank': 97,
#    'last_updated': '2019-12-04T16:36:13.000Z',
#    'quote': {'USD': {'price': 0.104984808231,
#      'volume_24h': 542115.674115874,
#      'percent_change_1h': -0.180327,
#      'percent_change_24h': -1.08074,
#      'percent_change_7d': 6.11722,
#      'market_cap': 36266213.29147295,
#      'last_updated': '2019-12-04T16:36:13.000Z'}}},
#   {'id': 2447,
#    'name': 'Crypterium',
#    'symbol': 'CRPT',
#    'slug': 'crpt',
#    'num_market_pairs': 9,
#    'date_added': '2018-01-22T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 84759818.6100001,
#    'total_supply': 99757369.7528572,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x80a7e048f37a50500351c204cb407766fa3bae7f'},
#    'cmc_rank': 98,
#    'last_updated': '2019-12-04T16:36:07.000Z',
#    'quote': {'USD': {'price': 0.422336217663,
#      'volume_24h': 312957.569310396,
#      'percent_change_1h': 0.775115,
#      'percent_change_24h': -3.12965,
#      'percent_change_7d': -5.57341,
#      'market_cap': 35797141.2015494,
#      'last_updated': '2019-12-04T16:36:07.000Z'}}},
#   {'id': 1229,
#    'name': 'DigixDAO',
#    'symbol': 'DGD',
#    'slug': 'digixdao',
#    'num_market_pairs': 27,
#    'date_added': '2016-04-18T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 2000000,
#    'total_supply': 2000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xe0b7927c4af23765cb51314a0e0521a9645f0e2a'},
#    'cmc_rank': 99,
#    'last_updated': '2019-12-04T16:36:03.000Z',
#    'quote': {'USD': {'price': 17.7531397063,
#      'volume_24h': 642484.986102053,
#      'percent_change_1h': -1.36146,
#      'percent_change_24h': -3.64697,
#      'percent_change_7d': 32.4611,
#      'market_cap': 35506279.4126,
#      'last_updated': '2019-12-04T16:36:03.000Z'}}},
#   {'id': 2989,
#    'name': 'STASIS EURO',
#    'symbol': 'EURS',
#    'slug': 'stasis-euro',
#    'num_market_pairs': 29,
#    'date_added': '2018-07-30T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 31979207,
#    'total_supply': 31979207,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xdb25f211ab05b1c97d595516f45794528a807ad8'},
#    'cmc_rank': 100,
#    'last_updated': '2019-12-04T16:36:10.000Z',
#    'quote': {'USD': {'price': 1.10184729963,
#      'volume_24h': 823678.396163858,
#      'percent_change_1h': -0.241448,
#      'percent_change_24h': 0.0803209,
#      'percent_change_7d': 0.441881,
#      'market_cap': 35236202.87725879,
#      'last_updated': '2019-12-04T16:36:10.000Z'}}}]}

# %%
url = "https://pro-api.coinmarketcap.com/v1/blockchain/statistics/latest"
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '8156fd5c-1e27-4c73-8393-fef3b616fe8d',
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    consensus_data = json.loads(response.text)
#     print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
# Out:
# {'status': {'timestamp': '2019-12-04T16:37:06.757Z', 'error_code': 0, 'error_message': None, 'elapsed': 15, 'credit_count': 1, 'notice': None}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 7719, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18083012, 'total_supply': 18083012, 'platform': None, 'cmc_rank': 1, 'last_updated': '2019-12-04T16:36:39.000Z', 'quote': {'USD': {'price': 7473.33358131, 'volume_24h': 19359325961.0166, 'percent_change_1h': -0.209582, 'percent_change_24h': 1.36571, 'percent_change_7d': 1.31537, 'market_cap': 135140380830.83171, 'last_updated': '2019-12-04T16:36:39.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 5336, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': None, 'circulating_supply': 108796454.749, 'total_supply': 108796454.749, 'platform': None, 'cmc_rank': 2, 'last_updated': '2019-12-04T16:36:23.000Z', 'quote': {'USD': {'price': 149.574425867, 'volume_24h': 7441687171.12115, 'percent_change_1h': -0.102632, 'percent_change_24h': 0.243996, 'percent_change_7d': -0.746315, 'market_cap': 16273167255.44672, 'last_updated': '2019-12-04T16:36:23.000Z'}}}, {'id': 52, 'name': 'XRP', 'symbol': 'XRP', 'slug': 'xrp', 'num_market_pairs': 508, 'date_added': '2013-08-04T00:00:00.000Z', 'tags': [], 'max_supply': 100000000000, 'circulating_supply': 43285660917, 'total_supply': 99991237614, 'platform': None, 'cmc_rank': 3, 'last_updated': '2019-12-04T16:36:06.000Z', 'quote': {'USD': {'price': 0.220124015908, 'volume_24h': 1339776344.04373, 'percent_change_1h': -0.144137, 'percent_change_24h': -0.631323, 'percent_change_7d': -1.33052, 'market_cap': 9528213512.282001, 'last_updated': '2019-12-04T16:36:06.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 3927, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': [], 'max_supply': None, 'circulating_supply': 4108044456.1, 'total_supply': 4207771504.46, 'platform': {'id': 83, 'name': 'Omni', 'symbol': 'OMNI', 'slug': 'omni', 'token_address': '31'}, 'cmc_rank': 4, 'last_updated': '2019-12-04T16:36:21.000Z', 'quote': {'USD': {'price': 1.00117825419, 'volume_24h': 22037500478.6887, 'percent_change_1h': -0.344664, 'percent_change_24h': -0.441049, 'percent_change_7d': -0.202884, 'market_cap': 4112884776.693106, 'last_updated': '2019-12-04T16:36:21.000Z'}}}, {'id': 1831, 'name': 'Bitcoin Cash', 'symbol': 'BCH', 'slug': 'bitcoin-cash', 'num_market_pairs': 440, 'date_added': '2017-07-23T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18148537.5, 'total_supply': 18148537.5, 'platform': None, 'cmc_rank': 5, 'last_updated': '2019-12-04T16:36:08.000Z', 'quote': {'USD': {'price': 214.724863297, 'volume_24h': 1405778696.8401, 'percent_change_1h': -0.361312, 'percent_change_24h': -0.158719, 'percent_change_7d': -1.00116, 'market_cap': 3896942233.727978, 'last_updated': '2019-12-04T16:36:08.000Z'}}}, {'id': 2, 'name': 'Litecoin', 'symbol': 'LTC', 'slug': 'litecoin', 'num_market_pairs': 557, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 84000000, 'circulating_supply': 63769119.2668217, 'total_supply': 63769119.2668217, 'platform': None, 'cmc_rank': 6, 'last_updated': '2019-12-04T16:36:06.000Z', 'quote': {'USD': {'price': 46.0341032287, 'volume_24h': 2864643850.02982, 'percent_change_1h': -0.227453, 'percent_change_24h': -0.583959, 'percent_change_7d': -2.96373, 'market_cap': 2935554219.132152, 'last_updated': '2019-12-04T16:36:06.000Z'}}}, {'id': 1765, 'name': 'EOS', 'symbol': 'EOS', 'slug': 'eos', 'num_market_pairs': 394, 'date_added': '2017-07-01T00:00:00.000Z', 'tags': [], 'max_supply': None, 'circulating_supply': 942932350.6709, 'total_supply': 1039632362.163, 'platform': None, 'cmc_rank': 7, 'last_updated': '2019-12-04T16:36:07.000Z', 'quote': {'USD': {'price': 2.69730896384, 'volu ...

# %%
consensus_data
# Out:
# {'status': {'timestamp': '2019-12-04T16:38:59.794Z',
#   'error_code': 1006,
#   'error_message': "Your API Key subscription plan doesn't support this endpoint.",
#   'elapsed': 0,
#   'credit_count': 0}}
