# %%
import pandas
import json
import requests
from bs4 import BeautifulSoup

url = "https://coinmarketcap.com"
content = requests.get(url).content
soup = BeautifulSoup(content, 'html.parser')

# %%
names = soup.find_all('a', class_='currency-name-container')
# Out:
# <!DOCTYPE doctype html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# ...

# %%
names = soup.find_all('a', class_='currency-name-container')
price = soup.find_all('a', class_='price')
volumne = soup.find_all('a', class_='volume')

# %%
price
# Out:
# [<a class="price" data-btc="1.0" data-usd="8803.88694804" href="/currencies/bitcoin/#markets">$8803.89</a>,
#  <a class="price" data-btc="0.0213373337356" data-usd="187.943543172" href="/currencies/ethereum/#markets">$187.94</a>,
#  <a class="price" data-btc="3.10829699819e-05" data-usd="0.273785074701" href="/currencies/ripple/#markets">$0.273785</a>,
#  <a class="price" data-btc="0.0325145866048" data-usd="286.395042934" href="/currencies/bitcoin-cash/#markets">$286.40</a>,
#  <a class="price" data-btc="0.000114250669417" data-usd="1.00634296141" href="/currencies/tether/#markets">$1.01</a>,
#  <a class="price" data-btc="0.00694919405063" data-usd="61.2099041171" href="/currencies/litecoin/#markets">$61.21</a>,
#  <a class="price" data-btc="0.00242033728099" data-usd="21.3188193941" href="/currencies/binance-coin/#markets">$21.32</a>,
#  <a class="price" data-btc="0.000393640808823" data-usd="3.46726771321" href="/currencies/eos/#markets">$3.47</a>,
# ...

# %%
for item in names[:100]:
    print(item.text)
# Out:
# Bitcoin
# Ethereum
# XRP
# Bitcoin Cash
# Tether
# Litecoin
# Binance Coin
# EOS
# Bitcoin SV
# Stellar
# TRON
# Cardano
# Monero
# Chainlink
# UNUS SED LEO
# Huobi Token
# NEO
# Cosmos
# Tezos
# IOTA
# Maker
# Dash
# Ethereum Classic
# Ontology
# USD Coin
# Crypto.com Coin
# NEM
# VeChain
# Basic Attenti...
# Dogecoin
# Zcash
# Decred
# Paxos Standard
# Qtum
# HedgeTrade
# 0x
# TrueUSD
# Holo
# V Systems
# Centrality
# Bitcoin Gold
# OmiseGO
# Ravencoin
# Nano
# ZB
# ABBC Coin
# Augur
# Algorand
# Bytom
# Synthetix Net...
# Komodo
# LUNA
# Dai
# KuCoin Shares
# Silverway
# EDUCare
# DxChain Token
# Bitcoin Diamond
# BitTorrent
# Lisk
# DigiByte
# Siacoin
# ICON
# HyperCash
# Quant
# Swipe
# THETA
# IOST
# Waves
# Karatgold Coin
# Bytecoin
# BitShares
# FTX Token
# MonaCoin
# MCO
# Aeternity
# Seele
# Aurora
# Verge
# iExec RLC
# Nexo
# MaidSafeCoin
# Chiliz
# Ardor
# BitMax Token
# Energi
# Zilliqa
# Steem
# Enjin Coin
# RIF Token
# Ren
# Status
# Crypterium
# Golem
# aelf
# Newton
# ...
